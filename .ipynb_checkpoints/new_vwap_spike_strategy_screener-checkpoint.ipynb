# %% [markdown]
# # IMPORT MODULES

# %%
import pandas as pd
import numpy as np
import random
import itertools
import json
import pprint
import datetime
from datetime import date, time, timedelta, datetime
import requests
import os
import pandas_market_calendars as mcal
import base64
from config import appKey, appSecret
from datetime import datetime, timedelta, date
import traceback
import glob

# %% [markdown]
# # STRATEGY INPUTS AND VARIABLES

# %%
## DEFINING ALL VARIABLES FO## DEFINING ALL VARIABLES FOR BACKTESTING

######################################## STRATEGY NOTE TO REMIND ON OUTPUT ########################################
strategy_note = '50M+Float'
run = strategy_note
day_of_backtest = datetime.now()
print(day_of_backtest)
########################################  IMPORT LIST OF ALL TICKERS FOR BACKTEST/STRATEGY   #################################
# ticker_list = pd.read_excel('./prod_files/by_float/group_2_float_11M_to_26M.xlsx')
ticker_list = pd.concat(map(pd.read_excel, glob.glob("./prod_files/by_float/*.xlsx")))
ticker_list = ticker_list[ticker_list['Float'] > 50000000]

####################################### SETTING CANDLE TIME FRAME FOR STRATEGY ########################################

# Define variables for stock time frame for strategy
period_type = 'day'  # Current value
period = 10          # Current value
frequency_type = 'minute'  # Current value
frequency = 30      # Current value
need_extended_hours_data = 'true'  # Current value
need_previous_close = 'true'  # Current value

######################################## TESTING COMBINATION OF INPUTS FOR STRATEGY  ########################################

TOTAL_CASH = 10000 #FIXED
ALLOCATION = .1
BET_SIZE = [ALLOCATION] #FIXED
STOP = [.1] #FIXED #Removed .05
TARGET = [.05] #FIXED


VOL_SPIKE_THRESHOLD = [5] #Abnormally high volume that stands out on a chart
PRICE_SPIKE_THRESHOLD = [.05] #Must move the price x%
TIME_SIG_THRESHOLD = [time(hour=12,minute=30,second=0)]
BUY_TIME_THRESHOLD = [time(hour=10,minute=30,second=0)]
SELL_TIME_THRESHOLD = [time(hour = 15,minute = 30,second =0)]

####################################### CREATE VARIABLES FOR INPUT STRATEGY TO TEST ##########################

bet_size_index = 0
stop_index = 1
target_index = 2
vol_spike_thresh_index = 3
price_spike_thresh_index = 4
time_sig_thresh_index = 5
buy_time_threshold_index = 6
sell_time_threshold_index = 7

variables = [BET_SIZE,STOP,TARGET,VOL_SPIKE_THRESHOLD,PRICE_SPIKE_THRESHOLD,TIME_SIG_THRESHOLD,BUY_TIME_THRESHOLD, SELL_TIME_THRESHOLD]
combinations = list(itertools.product(*variables))      

######################################## STRATEGY OUTPUT TABLE ########################################

#FINAL OUTPUT TO EVALUATE DIFFERENT STRATEGY COMBINATIONS

inputs = pd.DataFrame(columns=['Account Size',
                               'Bet_Size',
                               'Stop',
                               'Target',
                               'Vol Spike Thresh',
                               'Price Spike Thresh',
                               'Signal Time Threshold',
                               'Buy Time Threshold',
                               'Sell_Time',
                               'Signals',
                               'Buys',
                               'Win %',
                               'Average Win',
                               'Strategy Note'])

########################################  TIME FRAME  ########################################

# Set date parameters and calculations regarding dates such as 10 day rolling average volume

en = datetime.now() #SCREENER WILL RUN AS OF THIS DAY
st = en - timedelta(days=20)

days = (en-st).days

start_time = str(int(st.timestamp())*1000)
end_time = str(int(en.timestamp())*1000)

today = date.today()

time_interval = 30
time_interval_string = str(time_interval)+'m'
rolling_window_days = 10
tickers_per_day = 60/time_interval*6.5
rolling_lookback = rolling_window_days*tickers_per_day

# Find Next Business Day
# Import the New York Stock Exchange Calendar
nyse = mcal.get_calendar('NYSE')
open_close_schedule = pd.DataFrame(nyse.schedule(start_date=st, end_date=en))
open_close_schedule.index.names = ['Date']
open_close_schedule.reset_index(inplace=True)
open_close_schedule['Date'] = open_close_schedule['Date'].dt.date
open_close_schedule['market_open'] = open_close_schedule['market_open'] - timedelta(hours=4)
open_close_schedule['market_close'] = open_close_schedule['market_close'] - timedelta(hours=4, minutes=time_interval)
open_close_schedule['market_open'] = open_close_schedule['market_open'].dt.time
open_close_schedule['market_close'] = open_close_schedule['market_close'].dt.time

nyse_days = nyse.valid_days(start_date=st, end_date=en)
valid_trading_days = pd.Series(nyse_days).dt.date

schedule = pd.DataFrame(nyse.schedule(start_date=st, end_date=en))
# Out:
# 2024-10-28 09:06:46.703518

# %%
######################################### SCHWAB API FUNCTIONS ########################################################
def get_schwab_access_token():
    authUrl = f'https://api.schwabapi.com/v1/oauth/authorize?client_id={appKey}&redirect_uri=https://127.0.0.1'
    print(f"Click to authenticate: {authUrl}")
    returnedLink = input("Paste the redirect URL here:")
    code = f"{returnedLink[returnedLink.index('code=')+5:returnedLink.index('%40')]}@"

    headers = {
        'Authorization': f'Basic {base64.b64encode(bytes(f"{appKey}:{appSecret}", "utf-8")).decode("utf-8")}',
        'Content-Type': 'application/x-www-form-urlencoded'
    }
    data = {
        'grant_type': 'authorization_code',
        'code': code,
        'redirect_uri': 'https://127.0.0.1'
    }

    response = requests.post('https://api.schwabapi.com/v1/oauth/token', headers=headers, data=data)
    token_data = response.json()
    return token_data['access_token']


def auto_authenticate():
    token_file = 'schwab_token.json'
    
    # Check if token file exists and is not expired
    if os.path.exists(token_file):
        with open(token_file, 'r') as f:
            token_data = json.load(f)
        
        expires_at = datetime.fromisoformat(token_data['expires_at'])
        if expires_at > datetime.now():
            return token_data['access_token']
    
    # If no valid token, authenticate
    headers = {
        'Authorization': f'Basic {base64.b64encode(bytes(f"{appKey}:{appSecret}", "utf-8")).decode("utf-8")}',
        'Content-Type': 'application/x-www-form-urlencoded'
    }
    data = {
        'grant_type': 'client_credentials',
        'scope': 'openid'
    }

    response = requests.post('https://api.schwabapi.com/v1/oauth/token', headers=headers, data=data)
    if response.status_code != 200:
        raise Exception(f"Authentication failed: {response.text}")

    token_data = response.json()
    # Convert expires_in to an integer before using it
    expires_in = int(token_data.get('expires_in', 3600))  # Default to 1 hour if not present
    token_data['expires_at'] = (datetime.now() + timedelta(seconds=expires_in)).isoformat()

    # Save token data
    with open(token_file, 'w') as f:
        json.dump(token_data, f)

    return token_data['access_token']

def get_stock_price_history(symbol, access_token, period_type, period, frequency_type, frequency, start_date, end_date, need_extended_hours_data, need_previous_close):
    url = 'https://api.schwabapi.com/marketdata/v1/pricehistory'
    params = {
        'symbol': symbol,
        'periodType': period_type,
        'period': period,
        'frequencyType': frequency_type,
        'frequency': frequency,
        'startDate': start_date,
        'endDate': end_date,
        'needExtendedHoursData': need_extended_hours_data,
        'needPreviousClose': need_previous_close
    }
    headers = {'Authorization': f'Bearer {access_token}'}
    
    response = requests.get(url, params=params, headers=headers)
    return response.json()

    #DOCUMENTATION FOR API CALL
    # If the periodType is
    # • day - valid values are 1, 2, 3, 4, 5, 10
    # • month - valid values are 1, 2, 3, 6
    # • year - valid values are 1, 2, 3, 5, 10, 15, 20
    # • ytd - valid values are 1

    # If the period is not specified and the periodType is
    # • day - default period is 10.
    # • month - default period is 1.
    # • year - default period is 1.
    # • ytd - default period is 1.

    # period
    # frequencyType
    # string
    # (query)
    # The time frequencyType

    # If the periodType is
    # • day - valid value is minute
    # • month - valid values are daily, weekly
    # • year - valid values are daily, weekly, monthly
    # • ytd - valid values are daily, weekly

    # If frequencyType is not specified, default value depends on the periodType
    # • day - defaulted to minute.
    # • month - defaulted to weekly.
    # • year - defaulted to monthly.
    # • ytd - defaulted to weekly.

    # Available values : minute, daily, weekly, monthly


    # --
    # frequency
    # integer($int32)
    # (query)
    # The time frequency duration

    # If the frequencyType is
    # • minute - valid values are 1, 5, 10, 15, 30
    # • daily - valid value is 1
    # • weekly - valid value is 1
    # • monthly - valid value is 1

    # If frequency is not specified, default value is 1

    # frequency
    # startDate
    # integer($int64)
    # (query)
    # The start date, Time in milliseconds since the UNIX epoch eg 1451624400000
    # If not specified startDate will be (endDate - period) excluding weekends and holidays.

    # startDate
    # endDate
    # integer($int64)
    # (query)
    # The end date, Time in milliseconds since the UNIX epoch eg 1451624400000
    # If not specified, the endDate will default to the market close of previous business day.

    # Can use this API Wrapper or take as inspiration: https://github.com/tylerebowers/Schwab-API-Python/blob/main/docs/stream.md
####Create Function for input stats to track to easily just change the list
# # all STRATEGY INPUTS AND VARIABLES should be put into different config files

# %%
# Download data into memory
if 'Ticker' in ticker_list.columns:
    # Create a new DataFrame with only the 'Tickers' column
    tickers_df = ticker_list[['Ticker']].dropna()
    # Convert to a list of unique tickers
    tickers = tickers_df['Ticker'].unique().tolist()  # Extract unique tickers
    print(tickers)  # Display the list of tickers
    print('SUCESS IF YOU SEE TICKERS!!! ^^^^^^^')
else:
    print("Column 'Ticker' not found in the DataFrame.")
# Out:
# ['BL', 'ALKT', 'STEW', 'CRL', 'ZBRA', 'PASG', 'AX', 'KFY', 'JKS', 'HCC', 'MOD', 'LMND', 'AIZ', 'TRMD', 'SNA', 'THS', 'AREC', 'CENX', 'VSTO', 'GDOT', 'WFG', 'DRTS', 'WDI', 'TY', 'SGML', 'CBU', 'CLYM', 'EBS', 'MHK', 'HG', 'VBTX', 'PLTK', 'MGTX', 'TFSL', 'GRNT', 'OPI', 'RGEN', 'VTEX', 'ACP', 'MHD', 'ZG', 'PII', 'ZVRA', 'EOS', 'REPL', 'KLIC', 'ARW', 'HYPR', 'MLTX', 'SOL', 'CENTA', 'QNST', 'FULC', 'PCN', 'SANM', 'PRQR', 'SUPN', 'IQI', 'RGLS', 'GKOS', 'DXLG', 'IDA', 'NNOX', 'SLRC', 'BTSG', 'MIDD', 'HLI', 'MATV', 'PRIM', 'PAVS', 'EXFY', 'CRUS', 'MUJ', 'CION', 'VUZI', 'CNTB', 'BAP', 'FIVE', 'WHR', 'WIX', 'EPAC', 'HUBB', 'BHAT', 'CRTO', 'ARBK', 'PLRX', 'CHW', 'PRTS', 'PHR', 'CBT', 'AHT', 'BHK', 'EMBC', 'ELF', 'LIVN', 'NDSN', 'LECO', 'REYN', 'VGM', 'GRWG', 'PAM', 'BUSE', 'FUL', 'ACB', 'EOLS', 'ENV', 'RYTM', 'CTOS', 'KTB', 'BZUN', 'MMU', 'IVR', 'RS', 'IBOC', 'VTYX', 'TDG', 'PXLW', 'GPCR', 'PARR', 'NMCO', 'RNST', 'NMRA', 'ONL', 'LUNR', 'PTLO', 'EPAM', 'ABVX', 'ENSG', 'AGIO', 'ENOV', 'VNDA', 'RA', 'PTA', 'MMT', 'VKQ', 'OMER', 'PVH', 'VECO', 'AVAH', 'PTGX', 'WWD', 'POWI', 'DKS', 'GILT', 'ERII', 'OGS', 'CNNE', 'TWST', 'LEA', 'SKY', 'SR', 'KNF', 'OEC', 'UHS', 'LYRA', 'TRMK', 'TILE', 'ELBM', 'ESAB', 'ASND', 'SEDG', 'KRNY', 'OCFC', 'GDYN', 'CR', 'MMSI', 'CRMD', 'HLLY', 'PRKS', 'NVEE', 'WKC', 'CROX', 'OXSQ', 'SSYS', 'QTWO', 'KEX', 'ADD', 'CCCC', 'ALDX', 'KYMR', 'LLYVK', 'BFAM', 'COOK', 'ORLY', 'MRTN', 'FRME', 'ALE', 'JOE', 'ILPT', 'TNGX', 'KREF', 'UNFI', 'VERX', 'FFIV', 'URBN', 'MOH', 'HCAT', 'DRVN', 'QDEL', 'MGNX', 'RHP', 'RCAT', 'AKRO', 'MRCY', 'JAMF', 'ALVR', 'BIRK', 'LQDA', 'ALTR', 'CWT', 'BHR', 'SB', 'OVID', 'EMD', 'HTBK', 'WSFS', 'TK', 'XFLT', 'CALX', 'DLB', 'ZGN', 'FPH', 'PAX', 'WERN', 'MTSI', 'AAP', 'MTLS', 'GLYC', 'BV', 'GNRC', 'EWTX', 'WAT', 'MRUS', 'RXT', 'DAWN', 'CNTX', 'CFR', 'DOCN', 'ARVN', 'ARGX', 'MMS', 'NDMO', 'VOR', 'CRESY', 'JAZZ', 'CUE', 'UFPI', 'FSS', 'ASG', 'BHF', 'OIS', 'SKYX', 'PRDO', 'SIGI', 'ORA', 'RPD', 'CARS', 'HUBG', 'MANH', 'MLM', 'FPF', 'NWE', 'VRNT', 'BYND', 'CGNT', 'CHRD', 'PLAB', 'CWST', 'SPH', 'WIW', 'OLLI', 'EVC', 'RUSHA', 'ZNTL', 'BECN', 'DOLE', 'KMPR', 'MTZ', 'BOE', 'CLBT', 'ZTR', 'TRTX', 'ACIU', 'SN', 'BBN', 'GMRE', 'INVA', 'ABM', 'AGCO', 'IMVT', 'SDGR', 'KZR', 'COOP', 'BPMC', 'NCMI', 'LEO', 'GOGO', 'STEP', 'VERV', 'BIGC', 'XNET', 'DLO', 'CMPS', 'KODK', 'NICE', 'SCWO', 'VRNA', 'BMA', 'NOAH', 'CDMO', 'RYAM', 'GPRE', 'DK', 'EVTC', 'TKR', 'PNNT', 'RBRK', 'CLSD', 'ONDS', 'BURL', 'TERN', 'MMYT', 'MVF', 'ZIP', 'HNST', 'ESS', 'FOUR', 'LIF', 'SQSP', 'RDNT', 'SLS', 'BCSF', 'TIXT', 'PPTA', 'CLDX', 'SLRN', 'INGR', 'GLPG', 'KBDC', 'RAMP', 'OSK', 'AESI', 'SLG', 'EDD', 'WSBC', 'KURA', 'YELP', 'TNDM', 'LITE', 'NVEI', 'POET', 'DQ', 'FTCI', 'PSTX', 'IART', 'KLG', 'ENR', 'ABCB', 'TEX', 'SDRL', 'BC', 'TNYA', 'PRCH', 'WTFC', 'GLDD', 'CTLP', 'RGLD', 'ANGI', 'RGA', 'BTT', 'UIS', 'URI', 'USAC', 'BCYC', 'WHD', 'ATR', 'VAL', 'NABL', 'HFRO', 'BWIN', 'RRX', 'ACET', 'CRDL', 'TXRH', 'APLM', 'PML', 'CODI', 'CHDN', 'MYI', 'NEXN', 'ZCAR', 'CHY', 'AAON', 'BRCC', 'KRP', 'MKSI', 'MEOH', 'SWTX', 'UTZ', 'AY', 'TNL', 'VLN', 'CPAY', 'CANG', 'ETJ', 'AIEV', 'VMO', 'ACRS', 'LNTH', 'LINE', 'VRDN', 'VCIG', 'APAM', 'AS', 'LOAR', 'BYD', 'XNCR', 'PFMT', 'CRNT', 'MLKN', 'CATY', 'OMI', 'NTCT', 'QUBT', 'CNF', 'SHOO', 'CLMT', 'CDXS', 'TKO', 'LPX', 'ACCD', 'NSA', 'TGS', 'CLLS', 'NIU', 'GFR', 'BKH', 'WMS', 'ASO', 'INTA', 'ABAT', 'OKLO', 'ALGN', 'HI', 'HGV', 'NRIX', 'PODD', 'CHI', 'TOWN', 'LDI', True, 'PIII', 'YSG', 'MC', 'VSCO', 'LTH', 'LPSN', 'ALT', 'VEON', 'NATL', 'API', 'BPOP', 'KBH', 'SGRY', 'SEAT', 'ALEX', 'AGR', 'KLTR', 'ORC', 'MDB', 'BBU', 'SWX', 'WFRD', 'SSP', 'ATEN', 'AMPL', 'AXON', 'BEAM', 'CBAT', 'MQY', 'DOUG', 'MUI', 'OSUR', 'SY', 'WST', 'BBUC', 'BRZE', 'RPAY', 'JKHY', 'WAY', 'PFLT', 'IAS', 'KNDI', 'IVVD', 'HCSG', 'ALTO', 'DHF', 'AFG', 'FLNC', 'UMH', 'CRC', 'HITI', 'FIVN', 'PACK', 'DX', 'IRS', 'ADTN', 'RUM', 'DRS', 'JXN', 'ATYR', 'XENE', 'ONCY', 'AVIR', 'BKU', 'EPR', 'LPLA', 'SMTC', 'RDDT', 'PTCT', 'EVT', 'FFWM', 'ALEC', 'GUT', 'RSI', 'IT', 'BRY', ...
# SUCESS IF YOU SEE TICKERS!!! ^^^^^^^

# %%
# tickers = ['IONQ']  # Can easily change this to test different tickers
# print(f"Testing strategy on ticker: {tickers[0]}")

# %%
################################## TESTING/AUTHENTICATING CONNECTION TO SCHWAB API ##################################
# Get access token (figure out how often to do this optimally)
access_token = auto_authenticate()

# Get AAPL price history for the last year using the defined variables
aapl_price_history = get_stock_price_history('AAPL', access_token, period_type, period, frequency_type, frequency,  start_time, end_time,need_extended_hours_data, need_previous_close)

# Convert to DataFrame
aapl_df = pd.DataFrame(aapl_price_history['candles'])

# Rename columns to match the required format
aapl_df.rename(columns={
    'datetime': 'Datetime',
    'open': 'Open',
    'high': 'High',
    'low': 'Low',
    'close': 'Close',
    'volume': 'Volume'
}, inplace=True)

# Convert Datetime to EST
aapl_df['Datetime'] = pd.to_datetime(aapl_df['Datetime'], unit='ms').dt.tz_localize('UTC').dt.tz_convert('US/Eastern').dt.tz_localize(None)

# Save the DataFrame as a CSV file
# aapl_df.to_csv('./file_uploads/tests/aapl_price_history.csv', index=False)

# Print the result

# print(aapl_price_history)
print('SUCCESS IF I SEE APPLE STOCK DATA!!!')
# print('AAPL price history saved to ./file_uploads/tests/aapl_price_history.csv')
# Out:
# SUCCESS IF I SEE APPLE STOCK DATA!!!

# %% [markdown]
# # Get All Stock Data, Calculate Relevant Stats, and Store in DF's

# %%
######################### CREATE INITIAL DATAFRAME OF STOCK PRICE HISTORY AND PERFORM PRECALCULATIONS #########################

start_clock = datetime.now()  # calculate run time
go = 1
stockies = {} #Create dataframes of stock data for iteration

for ticker in tickers:
    # Get stock price history from Schwab API
    stock_data = get_stock_price_history(ticker, access_token, period_type, period, frequency_type, frequency, start_time, end_time, need_extended_hours_data, need_previous_close)
    
    if not stock_data or 'candles' not in stock_data:
        print(f"No data available for {ticker}")
        continue
    
    # Convert to DataFrame
    stahks = pd.DataFrame(stock_data['candles'])
    
    # Ensure all required fields are present
    required_fields = ['datetime', 'open', 'high', 'low', 'close', 'volume']
    if not all(field in stahks.columns for field in required_fields):
        print(f"Missing required fields for {ticker}. Available columns: {stahks.columns}")
        continue
    
    # Rename columns to match the required format
    stahks.rename(columns={
        'datetime': 'Datetime',
        'open': 'Open',
        'high': 'High',
        'low': 'Low',
        'close': 'Close',
        'volume': 'Volume'
    }, inplace=True)
    
    # Convert Datetime to EST
    stahks['Datetime'] = pd.to_datetime(stahks['Datetime'], unit='ms').dt.tz_localize('UTC').dt.tz_convert('US/Eastern').dt.tz_localize(None)
    
    # Print the DataFrame to inspect its structure
    # print(f"Data for {ticker}:")
    # print(stahks.head())  # Display the first few rows of the DataFrame
    # print("Columns in DataFrame:", stahks.columns)  # Print the column names
    
    #Skip stock if there is insufficient amount of data (data for each period of normal trading hours)
    end_check = stahks['Datetime'].max()
    start_check = stahks['Datetime'].min()
    daydiff = end_check.weekday() - start_check.weekday()
    days = ((end_check-start_check).days - daydiff) / 7 * 5 + min(daydiff,5) - (max(end_check.weekday() - 4, 0) % 5)
    
    print(ticker, len(stahks.index))    
    # Removed the erroneous line that referenced 'datetime' instead of 'Datetime'
    # stahks['datetime'] = pd.to_datetime(stahks['datetime']/1000, unit = 's')-timedelta(hours =4)
    # stahks.columns = ['Open','High','Low','Close','Volume','Datetime']
    
    #Rearrange Columns and Merge with Open/Close Schedule
    stahks['Ticker'] = ticker
    stahks['Date'] = stahks['Datetime'].dt.date
    stahks = stahks.merge(open_close_schedule,how = 'left', on = 'Date')

    # Only calculate and average volume if there is sufficient data
    rolling_lookback_int = int(rolling_lookback)
    stahks['10_Day_Avg_Vol'] = stahks.Volume.rolling(rolling_lookback_int, min_periods=rolling_lookback_int).mean()
    stahks['10_Day_Avg_Vol'] = stahks['10_Day_Avg_Vol'].fillna(float('inf'))
    stahks['Time'] = stahks['Datetime'].dt.time
    
    #Remove any accidental duplicates (FIGURE OUT WHY????)
    stahks.drop_duplicates(['Ticker','Date','Time'],inplace = True,ignore_index=True)
    
    if len(stahks.index) < (days * tickers_per_day):
        continue
        
    # Create column with the open bar's low price (For % gap up calculation with spike later in day)
    cond = (stahks['Time'] == stahks['market_open'])
    stahks['Day_Open_Low'] = stahks[cond].groupby('Date', as_index=True)['Low'].transform('min').ffill()

    stahks['After Hours'] = (stahks['Time'] > stahks['market_close']) | (stahks['Time'] < stahks['market_open'])

    cond_2 = (stahks['After Hours'] == True)
    stahks['Pre-Market High'] = stahks[cond_2].groupby('Date', as_index=True)['High'].transform('max')
    
    stahks = stahks.ffill(axis=0)
    stahks = stahks.bfill(axis=0)

    
    stahks['VWAP_Row'] = stahks['Volume']*((stahks['High']+stahks['Low']+stahks['Close'])/3)
    stahks['Cum_VWAP'] = stahks.groupby('Date')['VWAP_Row'].transform('cumsum')
    stahks['Cum_Volume'] = stahks.groupby('Date')['Volume'].transform('cumsum')
    stahks['VWAP'] = stahks['Cum_VWAP']/stahks['Cum_Volume']
    stahks['VWAP_STD_1'] = stahks['VWAP'] - stahks.groupby('Date')['VWAP'].transform('std')
    stahks['Color_Bar'] = np.where(stahks['Open']<=stahks['Close'], 'Green', 'Red')
    #vol_window = 1
    stahks['Day_Close'] = (stahks['Time'] == stahks['market_close'])

    
    stockies[ticker] = pd.DataFrame(stahks, columns=stahks.keys())
    print(f"{ticker} processed successfully.")
    go += 1

    #Calculate pre-market volume for day 
    #Calculate pre-market change for the day 
    #stockies['Ticker_Return'] = (stahks['Close']/stahks['Close'].shift(vol_window))-1
    #stockies['Rolling_Vol'] = stahks['Ticker_Return'].std(ddof=130)
    
    ##PRINT OUT THE DATAFRAME TO A CSV FILE
    # stahks.to_csv(f"screener_pre.csv", index=False, header=True)

#Stockies is the final dataframe that will be used for the backtest
# Out:
# BL 222
# BL processed successfully.
# ALKT 244
# ALKT processed successfully.
# STEW 210
# STEW processed successfully.
# CRL 236
# CRL processed successfully.
# ZBRA 221
# ZBRA processed successfully.
# PASG 247
# PASG processed successfully.
# AX 221
# AX processed successfully.
# KFY 215
# KFY processed successfully.
# JKS 430
# JKS processed successfully.
# HCC 242
# HCC processed successfully.
# MOD 235
# MOD processed successfully.
# LMND 334
# LMND processed successfully.
# AIZ 226
# AIZ processed successfully.
# TRMD 384
# TRMD processed successfully.
# SNA 226
# SNA processed successfully.
# THS 212
# THS processed successfully.
# AREC 250
# AREC processed successfully.
# CENX 245
# CENX processed successfully.
# VSTO 222
# VSTO processed successfully.
# GDOT 219
# GDOT processed successfully.
# WFG 210
# WFG processed successfully.
# DRTS 110
# WDI 220
# WDI processed successfully.
# TY 191
# TY processed successfully.
# SGML 253
# SGML processed successfully.
# CBU 213
# CBU processed successfully.
# CLYM 219
# CLYM processed successfully.
# EBS 307
# EBS processed successfully.
# MHK 234
# MHK processed successfully.
# HG 219
# HG processed successfully.
# VBTX 214
# VBTX processed successfully.
# PLTK 225
# PLTK processed successfully.
# MGTX 232
# MGTX processed successfully.
# TFSL 216
# TFSL processed successfully.
# GRNT 218
# GRNT processed successfully.
# OPI 306
# OPI processed successfully.
# RGEN 223
# RGEN processed successfully.
# VTEX 225
# VTEX processed successfully.
# ACP 255
# ACP processed successfully.
# MHD 203
# MHD processed successfully.
# ZG 250
# ZG processed successfully.
# PII 238
# PII processed successfully.
# ZVRA 236
# ZVRA processed successfully.
# EOS 216
# EOS processed successfully.
# REPL 212
# REPL processed successfully.
# KLIC 222
# KLIC processed successfully.
# ARW 221
# ARW processed successfully.
# HYPR 185
# HYPR processed successfully.
# MLTX 214
# MLTX processed successfully.
# SOL 234
# SOL processed successfully.
# CENTA 214
# CENTA processed successfully.
# QNST 211
# QNST processed successfully.
# FULC 237
# FULC processed successfully.
# PCN 225
# PCN processed successfully.
# SANM 219
# SANM processed successfully.
# PRQR 317
# PRQR processed successfully.
# SUPN 217
# SUPN processed successfully.
# IQI 212
# IQI processed successfully.
# RGLS 247
# RGLS processed successfully.
# GKOS 220
# GKOS processed successfully.
# DXLG 211
# DXLG processed successfully.
# IDA 213
# IDA processed successfully.
# NNOX 366
# NNOX processed successfully.
# SLRC 224
# SLRC processed successfully.
# BTSG 237
# BTSG processed successfully.
# MIDD 220
# MIDD processed successfully.
# HLI 213
# HLI processed successfully.
# MATV 212
# MATV processed successfully.
# PRIM 218
# PRIM processed successfully.
# PAVS 132
# EXFY 235
# EXFY processed successfully.
# CRUS 253
# CRUS processed successfully.
# MUJ 197
# MUJ processed successfully.
# CION 215
# CION processed successfully.
# VUZI 335
# VUZI processed successfully.
# CNTB 131
# BAP 216
# BAP processed successfully.
# FIVE 236
# FIVE processed successfully.
# WHR 260
# WHR processed successfully.
# WIX 226
# WIX processed successfully.
# EPAC 218
# EPAC processed successfully.
# HUBB 225
# HUBB processed successfully.
# BHAT 271
# BHAT processed successfully.
# CRTO 219
# CRTO processed successfully.
# ARBK 328
# ARBK processed successfully.
# PLRX 241
# PLRX processed successfully.
# CHW 209
# CHW processed successfully.
# PRTS 279
# PRTS processed successfully.
# PHR 220
# PHR processed successfully.
# CBT 218
# CBT processed successfully.
# AHT 240
# AHT processed successfully.
# BHK 210
# BHK processed successfully.
# EMBC 212
# EMBC processed successfully.
# ELF 359
# ELF processed successfully.
# LIVN 226
# LIVN processed successfully.
# NDSN 219
# NDSN processed successfully.
# LECO 218
# LECO processed successfully.
# REYN 223
# REYN processed successfully.
# VGM 206
# VGM processed successfully.
# GRWG 243
# GRWG processed successfully.
# PAM 223
# PAM processed successfully.
# BUSE 217
# BUSE processed successfully.
# FUL 210
# FUL processed successfully.
# ACB 329
# ACB processed successfully.
# EOLS 232
# EOLS processed successfully.
# ENV 210
# ENV processed successfully.
# RYTM 220
# RYTM processed successfully.
# CTOS 218
# CTOS processed successfully.
# KTB 216
# KTB processed successfully.
# BZUN 248
# BZUN processed successfully.
# MMU 205
# MMU processed successfully.
# IVR 308
# IVR processed successfully.
# RS 235
# RS processed successfully.
# IBOC 212
# IBOC processed successfully.
# VTYX 269
# VTYX processed successfully.
# TDG 216
# TDG processed successfully.
# PXLW 266
# PXLW processed successfully.
# GPCR 240
# GPCR processed successfully.
# PARR 237
# PARR processed successfully.
# NMCO 208
# NMCO processed successfully.
# RNST 214
# RNST processed successfully.
# NMRA 228
# NMRA processed successfully.
# ONL 234
# ONL processed successfully.
# LUNR 479
# LUNR processed successfully.
# PTLO 243
# PTLO processed successfully.
# EPAM 228
# EPAM processed successfully.
# ABVX 209
# ABVX processed successfully.
# ENSG 215
# ENSG processed successfully.
# AGIO 219
# AGIO processed successfully.
# ENOV 217
# ENOV processed successfully.
# VNDA 291
# VNDA processed successfully.
# RA 222
# RA processed successfully.
# PTA 204
# PTA processed successfully.
# MMT 200
# MMT processed successfully.
# VKQ 209
# VKQ processed successfully.
# OMER 215
# OMER processed successfully.
# PVH 228
# PVH processed successfully.
# VECO 223
# VECO processed successfully.
# AVAH 228
# AVAH processed successfully.
# PTGX 218
# PTGX processed successfully.
# WWD 220
# WWD processed successfully.
# POWI 219
# POWI processed successfully.
# DKS 231
# DKS processed successfully.
# GILT 242
# GILT processed successfully.
# ERII 214
# ERII processed successfully.
# OGS 216
# OGS processed successfully.
# CNNE 210
# CNNE processed successfully.
# TWST 234
# TWST processed successfully.
# LEA 236
# LEA processed successfully.
# SKY 219
# SKY processed successfully.
# SR 213
# SR processed successfully.
# KNF 217
# KNF processed successfully.
# OEC 213
# OEC processed successfully.
# UHS 232
# UHS processed successfully.
# LYRA 371
# LYRA processed successfully.
# TRMK 219
# TRMK processed successfully.
# TILE 220
# TILE processed successfully.
# ELBM 205
# ELBM processed successfully.
# ESAB 213
# ESAB processed successfully.
# ASND 226
# ASND processed successfully.
# SEDG 437
# SEDG processed successfully.
# KRNY 217
# KRNY processed successfully.
# OCFC 213
# OCFC processed successfully.
# GDYN 220
# GDYN processed successfully.
# CR 221
# CR processed successfully.
# MMSI 216
# MMSI processed successfully.
# CRMD 299
# CRMD processed successfully.
# HLLY 219
# HLLY processed successfully.
# PRKS 222
# PRKS processed successfully.
# NVEE 215
# NVEE processed successfully.
# WKC 218
# WKC processed successfully.
# CROX 317
# CROX processed successfully.
# OXSQ 274
# OXSQ processed successfully.
# SSYS 265
# SSYS processed successfully.
# QTWO 224
# QTWO processed successfully.
# KEX 220
# KEX processed successfully.
# ADD 406
# ADD processed successfully.
# CCCC 269
# CCCC processed successfully.
# ALDX 261
# ALDX processed successfully.
# KYMR 217
# KYMR processed successfully.
# LLYVK 215
# LLYVK processed successfully.
# BFAM 214
# BFAM processed successfully.
# COOK 213
# COOK processed successfully.
# ORLY 223
# ORLY processed successfully.
# MRTN 222
# MRTN processed successfully.
# FRME 219
# FRME processed successfully.
# ALE 218
# ALE processed successfully.
# JOE 222
# JOE processed successfully.
# ILPT 215
# ILPT processed successfully.
# TNGX 232
# TNGX processed successfully.
# KREF 222
# KREF processed successfully.
# UNFI 229
# UNFI processed successfully.
# VERX 228
# VERX processed successfully.
# FFIV 244
# FFIV processed successfully.
# URBN 230
# URBN processed successfully.
# MOH 251
# MOH processed successfully.
# HCAT 224
# HCAT processed successfully.
# DRVN 219
# DRVN processed successfully.
# QDEL 223
# QDEL processed successfully.
# MGNX 261
# MGNX processed successfully.
# RHP 220
# RHP processed successfully.
# RCAT 356
# RCAT processed successfully.
# AKRO 220
# AKRO processed successfully.
# MRCY 214
# MRCY processed successfully.
# JAMF 211
# JAMF processed successfully.
# ALVR 217
# ALVR processed successfully.
# BIRK 228
# BIRK processed successfully.
# LQDA 246
# LQDA processed successfully.
# ALTR 250
# ALTR processed successfully.
# CWT 211
# CWT processed successfully.
# BHR 211
# BHR processed successfully.
# SB 244
# SB processed successfully.
# OVID 227
# OVID processed successfully.
# EMD 222
# EMD processed successfully.
# HTBK 212
# HTBK processed successfully.
# WSFS 215
# WSFS processed successfully.
# TK 250
# TK processed successfully.
# XFLT 269
# XFLT processed successfully.
# CALX 222
# CALX processed successfully.
# DLB 220
# DLB processed successfully.
# ZGN 225
# ZGN processed successfully.
# FPH 231
# FPH processed successfully.
# PAX 228
# PAX processed successfully.
# WERN 220
# WERN processed successfully.
# MTSI 223
# MTSI processed successfully.
# AAP 335
# AAP processed successfully.
# MTLS 217
# MTLS processed successfully.
# GLYC 393
# GLYC processed successfully.
# BV 213
# BV processed successfully.
# GNRC 247
# GNRC processed successfully.
# EWTX 242
# EWTX processed successfully.
# WAT 231
# WAT processed successfully.
# MRUS 216
# MRUS processed successfully.
# RXT 238
# RXT processed successfully.
# DAWN 254
# DAWN processed successfully.
# CNTX 255
# CNTX processed successfully.
# CFR 214
# CFR processed successfully.
# DOCN 242
# DOCN processed successfully.
# ARVN 225
# ARVN processed successfully.
# ARGX 237
# ARGX processed successfully.
# MMS 214
# MMS processed successfully.
# NDMO 213
# NDMO processed successfully.
# VOR 277
# VOR processed successfully.
# CRESY 220
# CRESY processed successfully.
# JAZZ 231
# JAZZ processed successfully.
# CUE 274
# CUE processed successfully.
# UFPI 214
# UFPI processed successfully.
# FSS 216
# FSS processed successfully.
# ASG 216
# ASG processed successfully.
# BHF 214
# BHF processed successfully.
# OIS 231
# OIS processed successfully.
# SKYX 255
# SKYX processed successfully.
# PRDO 212
# PRDO processed successfully.
# SIGI 222
# SIGI processed successfully.
# ORA 255
# ORA processed successfully.
# RPD 241
# RPD processed successfully.
# CARS 212
# CARS processed successfully.
# HUBG 224
# HUBG processed successfully.
# MANH 221
# MANH processed successfully.
# MLM 227
# MLM processed successfully.
# FPF 211
# FPF processed successfully.
# NWE 218
# NWE processed successfully.
# VRNT 223
# VRNT processed successfully.
# BYND 368
# BYND processed successfully.
# CGNT 216
# CGNT processed successfully.
# CHRD 245
# CHRD processed successfully.
# PLAB 229
# PLAB processed successfully.
# CWST 228
# CWST processed successfully.
# SPH 212
# SPH processed successfully.
# WIW 210
# WIW processed successfully.
# OLLI 223
# OLLI processed successfully.
# EVC 226
# EVC processed successfully.
# RUSHA 219
# RUSHA processed successfully.
# ZNTL 257
# ZNTL processed successfully.
# BECN 227
# BECN processed successfully.
# DOLE 215
# DOLE processed successfully.
# KMPR 215
# KMPR processed successfully.
# MTZ 229
# MTZ processed successfully.
# BOE 212
# BOE processed successfully.
# CLBT 235
# CLBT processed successfully.
# ZTR 211
# ZTR processed successfully.
# TRTX 225
# TRTX processed successfully.
# ACIU 220
# ACIU processed successfully.
# SN 279
# SN processed successfully.
# BBN 214
# BBN processed successfully.
# GMRE 216
# GMRE processed successfully.
# INVA 214
# INVA processed successfully.
# ABM 213
# ABM processed successfully.
# AGCO 221
# AGCO processed successfully.
# IMVT 233
# IMVT processed successfully.
# SDGR 258
# SDGR processed successfully.
# KZR 281
# KZR processed successfully.
# COOP 226
# COOP processed successfully.
# BPMC 229
# BPMC processed successfully.
# NCMI 212
# NCMI processed successfully.
# LEO 207
# LEO processed successfully.
# GOGO 227
# GOGO processed successfully.
# STEP 222
# STEP processed successfully.
# VERV 248
# VERV processed successfully.
# BIGC 238
# BIGC processed successfully.
# XNET 210
# XNET processed successfully.
# DLO 255
# DLO processed successfully.
# CMPS 268
# CMPS processed successfully.
# KODK 250
# KODK processed successfully.
# NICE 237
# NICE processed successfully.
# SCWO 218
# SCWO processed successfully.
# VRNA 260
# VRNA processed successfully.
# BMA 214
# BMA processed successfully.
# NOAH 225
# NOAH processed successfully.
# CDMO 218
# CDMO processed successfully.
# RYAM 237
# RYAM processed successfully.
# GPRE 228
# GPRE processed successfully.
# DK 243
# DK processed successfully.
# EVTC 221
# EVTC processed successfully.
# TKR 214
# TKR processed successfully.
# PNNT 252
# PNNT processed successfully.
# RBRK 274
# RBRK processed successfully.
# CLSD 338
# CLSD processed successfully.
# ONDS 241
# ONDS processed successfully.
# BURL 228
# BURL processed successfully.
# TERN 267
# TERN processed successfully.
# MMYT 239
# MMYT processed successfully.
# MVF 203
# MVF processed successfully.
# ZIP 211
# ZIP processed successfully.
# HNST 388
# HNST processed successfully.
# ESS 227
# ESS processed successfully.
# FOUR 240
# FOUR processed successfully.
# LIF 235
# LIF processed successfully.
# SQSP 50
# SQSP processed successfully.
# RDNT 230
# RDNT processed successfully.
# SLS 326
# SLS processed successfully.
# BCSF 217
# BCSF processed successfully.
# TIXT 212
# TIXT processed successfully.
# PPTA 238
# PPTA processed successfully.
# CLDX 240
# CLDX processed successfully.
# SLRN 222
# SLRN processed successfully.
# INGR 213
# INGR processed successfully.
# GLPG 269
# GLPG processed successfully.
# KBDC 187
# KBDC processed successfully.
# RAMP 219
# RAMP processed successfully.
# OSK 226
# OSK processed successfully.
# AESI 232
# AESI processed successfully.
# SLG 250
# SLG processed successfully.
# EDD 212
# EDD processed successfully.
# WSBC 213
# WSBC processed successfully.
# KURA 221
# KURA processed successfully.
# YELP 241
# YELP processed successfully.
# TNDM 233
# TNDM processed successfully.
# LITE 269
# LITE processed successfully.
# NVEI 229
# NVEI processed successfully.
# POET 368
# POET processed successfully.
# DQ 379
# DQ processed successfully.
# FTCI 366
# FTCI processed successfully.
# PSTX 222
# PSTX processed successfully.
# IART 217
# IART processed successfully.
# KLG 227
# KLG processed successfully.
# ENR 215
# ENR processed successfully.
# ABCB 214
# ABCB processed successfully.
# TEX 224
# TEX processed successfully.
# SDRL 251
# SDRL processed successfully.
# BC 221
# BC processed successfully.
# TNYA 286
# TNYA processed successfully.
# PRCH 278
# PRCH processed successfully.
# WTFC 220
# WTFC processed successfully.
# GLDD 221
# GLDD processed successfully.
# CTLP 235
# CTLP processed successfully.
# RGLD 219
# RGLD processed successfully.
# ANGI 217
# ANGI processed successfully.
# RGA 223
# RGA processed successfully.
# BTT 212
# BTT processed successfully.
# UIS 244
# UIS processed successfully.
# URI 226
# URI processed successfully.
# USAC 223
# USAC processed successfully.
# BCYC 217
# BCYC processed successfully.
# WHD 224
# WHD processed successfully.
# ATR 222
# ATR processed successfully.
# VAL 282
# VAL processed successfully.
# NABL 213
# NABL processed successfully.
# HFRO 213
# HFRO processed successfully.
# BWIN 222
# BWIN processed successfully.
# RRX 222
# RRX processed successfully.
# ACET 250
# ACET processed successfully.
# CRDL 247
# CRDL processed successfully.
# TXRH 242
# TXRH processed successfully.
# APLM 336
# APLM processed successfully.
# PML 213
# PML processed successfully.
# CODI 221
# CODI processed successfully.
# CHDN 223
# CHDN processed successfully.
# MYI 208
# MYI processed successfully.
# NEXN 237
# NEXN processed successfully.
# ZCAR 351
# ZCAR processed successfully.
# CHY 212
# CHY processed successfully.
# AAON 221
# AAON processed successfully.
# BRCC 263
# BRCC processed successfully.
# KRP 218
# KRP processed successfully.
# MKSI 231
# MKSI processed successfully.
# MEOH 221
# MEOH processed successfully.
# SWTX 234
# SWTX processed successfully.
# UTZ 225
# UTZ processed successfully.
# AY 213
# AY processed successfully.
# TNL 212
# TNL processed successfully.
# VLN 223
# VLN processed successfully.
# CPAY 243
# CPAY processed successfully.
# CANG 203
# CANG processed successfully.
# ETJ 212
# ETJ processed successfully.
# AIEV 205
# AIEV processed successfully.
# VMO 214
# VMO processed successfully.
# ACRS 271
# ACRS processed successfully.
# LNTH 229
# LNTH processed successfully.
# LINE 215
# LINE processed successfully.
# VRDN 231
# VRDN processed successfully.
# VCIG 467
# VCIG processed successfully.
# APAM 225
# APAM processed successfully.
# AS 271
# AS processed successfully.
# LOAR 220
# LOAR processed successfully.
# BYD 224
# BYD processed successfully.
# XNCR 212
# XNCR processed successfully.
# PFMT 198
# PFMT processed successfully.
# CRNT 235
# CRNT processed successfully.
# MLKN 218
# MLKN processed successfully.
# CATY 222
# CATY processed successfully.
# OMI 219
# OMI processed successfully.
# NTCT 219
# NTCT processed successfully.
# QUBT 442
# QUBT processed successfully.
# CNF 195
# CNF processed successfully.
# SHOO 214
# SHOO processed successfully.
# CLMT 243
# CLMT processed successfully.
# CDXS 226
# CDXS processed successfully.
# TKO 230
# TKO processed successfully.
# LPX 232
# LPX processed successfully.
# ACCD 266
# ACCD processed successfully.
# NSA 222
# NSA processed successfully.
# TGS 214
# TGS processed successfully.
# CLLS 196
# CLLS processed successfully.
# NIU 299
# NIU processed successfully.
# GFR 208
# GFR processed successfully.
# BKH 217
# BKH processed successfully.
# WMS 230
# WMS processed successfully.
# ASO 228
# ASO processed successfully.
# INTA 221
# INTA processed successfully.
# ABAT 274
# ABAT processed successfully.
# OKLO 480
# OKLO processed successfully.
# ALGN 249
# ALGN processed successfully.
# HI 214
# HI processed successfully.
# HGV 222
# HGV processed successfully.
# NRIX 231
# NRIX processed successfully.
# PODD 223
# PODD processed successfully.
# CHI 206
# CHI processed successfully.
# TOWN 219
# TOWN processed successfully.
# LDI 246
# LDI processed successfully.
# Missing required fields for True. Available columns: RangeIndex(start=0, stop=0, step=1)
# PIII 276
# PIII processed successfully.
# YSG 239
# YSG processed successfully.
# MC 224
# MC processed successfully.
# VSCO 263
# VSCO processed successfully.
# LTH 253
# LTH processed successfully.
# LPSN 363
# LPSN processed successfully.
# ALT 369
# ALT processed successfully.
# VEON 184
# VEON processed successfully.
# NATL 211
# NATL processed successfully.
# API 288
# API processed successfully.
# BPOP 220
# BPOP processed successfully.
# KBH 255
# KBH processed successfully.
# SGRY 224
# SGRY processed successfully.
# SEAT 234
# SEAT processed successfully.
# ALEX 210
# ALEX processed successfully.
# AGR 215
# AGR processed successfully.
# KLTR 204
# KLTR processed successfully.
# ORC 372
# ORC processed successfully.
# MDB 297
# MDB processed successfully.
# BBU 142
# SWX 214
# SWX processed successfully.
# WFRD 237
# WFRD processed successfully.
# SSP 223
# SSP processed successfully.
# ATEN 212
# ATEN processed successfully.
# AMPL 217
# AMPL processed successfully.
# AXON 233
# AXON processed successfully.
# BEAM 253
# BEAM processed successfully.
# CBAT 266
# CBAT processed successfully.
# MQY 210
# MQY processed successfully.
# DOUG 229
# DOUG processed successfully.
# MUI 213
# MUI processed successfully.
# OSUR 216
# OSUR processed successfully.
# SY 154
# WST 235
# WST processed successfully.
# BBUC 193
# BBUC processed successfully.
# BRZE 262
# BRZE processed successfully.
# RPAY 211
# RPAY processed successfully.
# JKHY 224
# JKHY processed successfully.
# WAY 232
# WAY processed successfully.
# PFLT 281
# PFLT processed successfully.
# IAS 231
# IAS processed successfully.
# KNDI 238
# KNDI processed successfully.
# IVVD 278
# IVVD processed successfully.
# HCSG 212
# HCSG processed successfully.
# ALTO 233
# ALTO processed successfully.
# DHF 206
# DHF processed successfully.
# AFG 215
# AFG processed successfully.
# FLNC 324
# FLNC processed successfully.
# UMH 210
# UMH processed successfully.
# CRC 228
# CRC processed successfully.
# HITI 311
# HITI processed successfully.
# FIVN 242
# FIVN processed successfully.
# PACK 218
# PACK processed successfully.
# DX 326
# DX processed successfully.
# IRS 215
# IRS processed successfully.
# ADTN 223
# ADTN processed successfully.
# RUM 440
# RUM processed successfully.
# DRS 233
# DRS processed successfully.
# JXN 223
# JXN processed successfully.
# ATYR 334
# ATYR processed successfully.
# XENE 215
# XENE processed successfully.
# ONCY 277
# ONCY processed successfully.
# AVIR 216
# AVIR processed successfully.
# BKU 221
# BKU processed successfully.
# EPR 244
# EPR processed successfully.
# LPLA 229
# LPLA processed successfully.
# SMTC 249
# SMTC processed successfully.
# RDDT 408
# RDDT processed successfully.
# PTCT 230
# PTCT processed successfully.
# EVT 213
# EVT processed successfully.
# FFWM 217
# FFWM processed successfully.
# ALEC 229
# ALEC processed successfully.
# GUT 221
# GUT processed successfully.
# RSI 252
# RSI processed successfully.
# IT 221
# IT processed successfully.
# BRY 240
# BRY processed successfully.
# NAUT 213
# NAUT processed successfully.
# EB 227
# EB processed successfully.
# SRRK 248
# SRRK processed successfully.
# DJT 480
# DJT processed successfully.
# INMD 322
# INMD processed successfully.
# SA 266
# SA processed successfully.
# DYN 272
# DYN processed successfully.
# IAC 228
# IAC processed successfully.
# TVTX 239
# TVTX processed successfully.
# SSB 221
# SSB processed successfully.
# SNX 224
# SNX processed successfully.
# IEX 223
# IEX processed successfully.
# VCYT 226
# VCYT processed successfully.
# PNFP 213
# PNFP processed successfully.
# TGI 234
# TGI processed successfully.
# ASPN 401
# ASPN processed successfully.
# HUYA 336
# HUYA processed successfully.
# OGI 287
# OGI processed successfully.
# STRO 222
# STRO processed successfully.
# EYEN 337
# EYEN processed successfully.
# Missing required fields for HEI-A. Available columns: RangeIndex(start=0, stop=0, step=1)
# BSTZ 221
# BSTZ processed successfully.
# MSCI 213
# MSCI processed successfully.
# NCZ 216
# NCZ processed successfully.
# ALLK 315
# ALLK processed successfully.
# CNSL 220
# CNSL processed successfully.
# FTDR 218
# FTDR processed successfully.
# ETG 215
# ETG processed successfully.
# PGNY 250
# PGNY processed successfully.
# BDSX 227
# BDSX processed successfully.
# YOU 302
# YOU processed successfully.
# IDYA 228
# IDYA processed successfully.
# FORM 243
# FORM processed successfully.
# WIMI 271
# WIMI processed successfully.
# PROK 227
# PROK processed successfully.
# IVT 211
# IVT processed successfully.
# AXS 215
# AXS processed successfully.
# CTMX 321
# CTMX processed successfully.
# IMAB 272
# IMAB processed successfully.
# BGS 240
# BGS processed successfully.
# KMT 218
# KMT processed successfully.
# EYE 216
# EYE processed successfully.
# PCH 220
# PCH processed successfully.
# NTST 219
# NTST processed successfully.
# UPST 466
# UPST processed successfully.
# WH 232
# WH processed successfully.
# SKIN 225
# SKIN processed successfully.
# VZIO 224
# VZIO processed successfully.
# NRGV 303
# NRGV processed successfully.
# STR 223
# STR processed successfully.
# BWLP 299
# BWLP processed successfully.
# PDCO 224
# PDCO processed successfully.
# ORGO 212
# ORGO processed successfully.
# NR 217
# NR processed successfully.
# AVA 211
# AVA processed successfully.
# CRK 246
# CRK processed successfully.
# SKE 229
# SKE processed successfully.
# WOOF 294
# WOOF processed successfully.
# UDMY 239
# UDMY processed successfully.
# EXPI 232
# EXPI processed successfully.
# AHH 224
# AHH processed successfully.
# NMIH 214
# NMIH processed successfully.
# HGTY 196
# HGTY processed successfully.
# DSX 246
# DSX processed successfully.
# NVRI 219
# NVRI processed successfully.
# WW 437
# WW processed successfully.
# GTI 190
# GTI processed successfully.
# WWW 218
# WWW processed successfully.
# MXL 250
# MXL processed successfully.
# FLUT 295
# FLUT processed successfully.
# NBXG 217
# NBXG processed successfully.
# CIM 227
# CIM processed successfully.
# IGD 212
# IGD processed successfully.
# Missing required fields for AKO-B. Available columns: RangeIndex(start=0, stop=0, step=1)
# GOEV 459
# GOEV processed successfully.
# Missing required fields for AKO-A. Available columns: RangeIndex(start=0, stop=0, step=1)
# FHI 215
# FHI processed successfully.
# SUPV 225
# SUPV processed successfully.
# UTG 244
# UTG processed successfully.
# TDUP 256
# TDUP processed successfully.
# MAPS 247
# MAPS processed successfully.
# ADCT 229
# ADCT processed successfully.
# OCSL 232
# OCSL processed successfully.
# AVY 230
# AVY processed successfully.
# AQST 307
# AQST processed successfully.
# SNDX 222
# SNDX processed successfully.
# TFII 227
# TFII processed successfully.
# BLRX 266
# BLRX processed successfully.
# CRBU 270
# CRBU processed successfully.
# SMR 480
# SMR processed successfully.
# ALV 316
# ALV processed successfully.
# WAFD 217
# WAFD processed successfully.
# CMRX 248
# CMRX processed successfully.
# PUMP 234
# PUMP processed successfully.
# CNTA 221
# CNTA processed successfully.
# RNG 226
# RNG processed successfully.
# ULCC 288
# ULCC processed successfully.
# DVA 225
# DVA processed successfully.
# MHLD 207
# MHLD processed successfully.
# HSAI 292
# HSAI processed successfully.
# CWEN 235
# CWEN processed successfully.
# HUT 469
# HUT processed successfully.
# VALN 130
# HXL 241
# HXL processed successfully.
# PYCR 220
# PYCR processed successfully.
# GDRX 245
# GDRX processed successfully.
# ITT 222
# ITT processed successfully.
# TRN 221
# TRN processed successfully.
# FBRT 218
# FBRT processed successfully.
# JBHT 243
# JBHT processed successfully.
# IDXX 219
# IDXX processed successfully.
# ARKO 212
# ARKO processed successfully.
# CRSP 329
# CRSP processed successfully.
# EDIT 319
# EDIT processed successfully.
# MOVE 254
# MOVE processed successfully.
# REKR 264
# REKR processed successfully.
# GWRE 222
# GWRE processed successfully.
# VIRT 226
# VIRT processed successfully.
# ICLR 242
# ICLR processed successfully.
# AVXL 269
# AVXL processed successfully.
# ASAN 272
# ASAN processed successfully.
# BHVN 249
# BHVN processed successfully.
# SLGN 215
# SLGN processed successfully.
# STER 191
# STER processed successfully.
# DNUT 264
# DNUT processed successfully.
# CARG 217
# CARG processed successfully.
# EVRI 210
# EVRI processed successfully.
# OPT 165
# JELD 210
# JELD processed successfully.
# ATMU 221
# ATMU processed successfully.
# MRC 215
# MRC processed successfully.
# BLMN 231
# BLMN processed successfully.
# BOWL 223
# BOWL processed successfully.
# FRT 215
# FRT processed successfully.
# SXC 223
# SXC processed successfully.
# DCGO 227
# DCGO processed successfully.
# AHCO 216
# AHCO processed successfully.
# MAIN 253
# MAIN processed successfully.
# TPG 224
# TPG processed successfully.
# IMTX 227
# IMTX processed successfully.
# LH 222
# LH processed successfully.
# SBCF 212
# SBCF processed successfully.
# FL 275
# FL processed successfully.
# RCKT 253
# RCKT processed successfully.
# ELP 224
# ELP processed successfully.
# YETI 238
# YETI processed successfully.
# ANNX 238
# ANNX processed successfully.
# CGC 451
# CGC processed successfully.
# GTN 216
# GTN processed successfully.
# PLNT 231
# PLNT processed successfully.
# ZYME 230
# ZYME processed successfully.
# BCX 215
# BCX processed successfully.
# IVA 294
# IVA processed successfully.
# UNCY 382
# UNCY processed successfully.
# MD 218
# MD processed successfully.
# CRNX 242
# CRNX processed successfully.
# LAZ 218
# LAZ processed successfully.
# CGEN 243
# CGEN processed successfully.
# EFC 292
# EFC processed successfully.
# REAL 262
# REAL processed successfully.
# SCS 221
# SCS processed successfully.
# CHKP 237
# CHKP processed successfully.
# DSGX 212
# DSGX processed successfully.
# HQY 216
# HQY processed successfully.
# TCPC 250
# TCPC processed successfully.
# HWC 214
# HWC processed successfully.
# AWP 232
# AWP processed successfully.
# ESTC 249
# ESTC processed successfully.
# BNGO 406
# BNGO processed successfully.
# ADNT 233
# ADNT processed successfully.
# PMT 249
# PMT processed successfully.
# CMPX 258
# CMPX processed successfully.
# APLT 241
# APLT processed successfully.
# GFS 301
# GFS processed successfully.
# BRKL 216
# BRKL processed successfully.
# DRD 298
# DRD processed successfully.
# COGT 222
# COGT processed successfully.
# OC 238
# OC processed successfully.
# PFN 219
# PFN processed successfully.
# AWF 213
# AWF processed successfully.
# RARE 224
# RARE processed successfully.
# ELME 210
# ELME processed successfully.
# JBGS 217
# JBGS processed successfully.
# SCCO 260
# SCCO processed successfully.
# ALSN 226
# ALSN processed successfully.
# KN 215
# KN processed successfully.
# AVT 223
# AVT processed successfully.
# RENB 283
# RENB processed successfully.
# ALLE 229
# ALLE processed successfully.
# POWW 314
# POWW processed successfully.
# BW 269
# BW processed successfully.
# ALHC 227
# ALHC processed successfully.
# ANSS 231
# ANSS processed successfully.
# LAMR 213
# LAMR processed successfully.
# NRK 203
# NRK processed successfully.
# FUTU 477
# FUTU processed successfully.
# PD 224
# PD processed successfully.
# MYGN 223
# MYGN processed successfully.
# NWS 215
# NWS processed successfully.
# IMUX 347
# IMUX processed successfully.
# WRBY 259
# WRBY processed successfully.
# CDLR 209
# CDLR processed successfully.
# MYPS 209
# MYPS processed successfully.
# VIR 240
# VIR processed successfully.
# LNW 219
# LNW processed successfully.
# PKG 221
# PKG processed successfully.
# ARLP 236
# ARLP processed successfully.
# AUB 216
# AUB processed successfully.
# W 384
# W processed successfully.
# ASRT 251
# ASRT processed successfully.
# TXNM 212
# TXNM processed successfully.
# HAIN 218
# HAIN processed successfully.
# AGRO 225
# AGRO processed successfully.
# TWKS 223
# TWKS processed successfully.
# NYMT 281
# NYMT processed successfully.
# MSDL 224
# MSDL processed successfully.
# GL 224
# GL processed successfully.
# FTRE 236
# FTRE processed successfully.
# AVNT 216
# AVNT processed successfully.
# SRPT 229
# SRPT processed successfully.
# GDV 208
# GDV processed successfully.
# HESM 230
# HESM processed successfully.
# CORT 249
# CORT processed successfully.
# HIX 216
# HIX processed successfully.
# NFG 214
# NFG processed successfully.
# MRSN 228
# MRSN processed successfully.
# ACHC 267
# ACHC processed successfully.
# FIBK 218
# FIBK processed successfully.
# ABSI 269
# ABSI processed successfully.
# AVDL 230
# AVDL processed successfully.
# NCV 212
# NCV processed successfully.
# VRE 212
# VRE processed successfully.
# SMPL 216
# SMPL processed successfully.
# TPH 235
# TPH processed successfully.
# PBF 302
# PBF processed successfully.
# WTTR 218
# WTTR processed successfully.
# NEP 366
# NEP processed successfully.
# PB 226
# PB processed successfully.
# BWXT 267
# BWXT processed successfully.
# APPS 364
# APPS processed successfully.
# RSKD 219
# RSKD processed successfully.
# FCPT 214
# FCPT processed successfully.
# CTV 243
# CTV processed successfully.
# AMPS 262
# AMPS processed successfully.
# SVRA 225
# SVRA processed successfully.
# ECC 295
# ECC processed successfully.
# BMBL 267
# BMBL processed successfully.
# FROG 236
# FROG processed successfully.
# ACCO 217
# ACCO processed successfully.
# TSLX 210
# TSLX processed successfully.
# SRCL 218
# SRCL processed successfully.
# ZH 242
# ZH processed successfully.
# SG 334
# SG processed successfully.
# NOG 242
# NOG processed successfully.
# PLYA 216
# PLYA processed successfully.
# MFIC 220
# MFIC processed successfully.
# MBLY 449
# MBLY processed successfully.
# GLNG 237
# GLNG processed successfully.
# ASTL 217
# ASTL processed successfully.
# BTZ 221
# BTZ processed successfully.
# FGEN 329
# FGEN processed successfully.
# THC 247
# THC processed successfully.
# FFBC 214
# FFBC processed successfully.
# CIVI 249
# CIVI processed successfully.
# CVAC 269
# CVAC processed successfully.
# GEL 215
# GEL processed successfully.
# GO 231
# GO processed successfully.
# WYNN 295
# WYNN processed successfully.
# VLRS 257
# VLRS processed successfully.
# ZS 301
# ZS processed successfully.
# QRVO 277
# QRVO processed successfully.
# VIST 271
# VIST processed successfully.
# MUC 210
# MUC processed successfully.
# PPBI 213
# PPBI processed successfully.
# OSW 212
# OSW processed successfully.
# OABI 217
# OABI processed successfully.
# DBVT 282
# DBVT processed successfully.
# EQIX 218
# EQIX processed successfully.
# JWN 259
# JWN processed successfully.
# TDC 231
# TDC processed successfully.
# ARLO 223
# ARLO processed successfully.
# ERO 227
# ERO processed successfully.
# ARAY 231
# ARAY processed successfully.
# TRNO 216
# TRNO processed successfully.
# GLBE 240
# GLBE processed successfully.
# NFJ 208
# NFJ processed successfully.
# FATE 234
# FATE processed successfully.
# MCW 229
# MCW processed successfully.
# LEVI 266
# LEVI processed successfully.
# RVNC 255
# RVNC processed successfully.
# HIO 218
# HIO processed successfully.
# HP 230
# HP processed successfully.
# BLNK 395
# BLNK processed successfully.
# LVO 320
# LVO processed successfully.
# RES 230
# RES processed successfully.
# REAX 237
# REAX processed successfully.
# FUN 229
# FUN processed successfully.
# PPT 211
# PPT processed successfully.
# ZTEK 178
# NCNO 233
# NCNO processed successfully.
# CAVA 366
# CAVA processed successfully.
# DEA 242
# DEA processed successfully.
# BGNE 222
# BGNE processed successfully.
# UTF 228
# UTF processed successfully.
# CHTR 240
# CHTR processed successfully.
# VRSN 222
# VRSN processed successfully.
# NMFC 240
# NMFC processed successfully.
# DTM 221
# DTM processed successfully.
# MXCT 216
# MXCT processed successfully.
# ATS 210
# ATS processed successfully.
# QSI 288
# QSI processed successfully.
# SON 212
# SON processed successfully.
# HLF 261
# HLF processed successfully.
# NVCR 303
# NVCR processed successfully.
# SFIX 261
# SFIX processed successfully.
# VOYA 219
# VOYA processed successfully.
# WTI 320
# WTI processed successfully.
# HUMA 392
# HUMA processed successfully.
# AMP 225
# AMP processed successfully.
# FAF 218
# FAF processed successfully.
# AMKR 285
# AMKR processed successfully.
# RYAN 227
# RYAN processed successfully.
# TDS 227
# TDS processed successfully.
# STE 222
# STE processed successfully.
# CHGG 330
# CHGG processed successfully.
# ZLAB 253
# ZLAB processed successfully.
# ATEC 270
# ATEC processed successfully.
# ACTG 217
# ACTG processed successfully.
# NJR 213
# NJR processed successfully.
# PINC 211
# PINC processed successfully.
# ITCI 232
# ITCI processed successfully.
# NBIX 230
# NBIX processed successfully.
# ADC 240
# ADC processed successfully.
# TTMI 228
# TTMI processed successfully.
# SF 223
# SF processed successfully.
# EHC 226
# EHC processed successfully.
# Missing required fields for UHAL-B. Available columns: RangeIndex(start=0, stop=0, step=1)
# BBAI 467
# BBAI processed successfully.
# BILL 232
# BILL processed successfully.
# LUXH 470
# LUXH processed successfully.
# ZIM 453
# ZIM processed successfully.
# ETNB 224
# ETNB processed successfully.
# OII 231
# OII processed successfully.
# SFM 276
# SFM processed successfully.
# TXG 320
# TXG processed successfully.
# LND 224
# LND processed successfully.
# NTLA 353
# NTLA processed successfully.
# EVGO 418
# EVGO processed successfully.
# AVPT 229
# AVPT processed successfully.
# TIGO 234
# TIGO processed successfully.
# WTW 229
# WTW processed successfully.
# XHR 211
# XHR processed successfully.
# MFA 247
# MFA processed successfully.
# FSLR 399
# FSLR processed successfully.
# TMHC 237
# TMHC processed successfully.
# ARQT 283
# ARQT processed successfully.
# ECAT 232
# ECAT processed successfully.
# EGY 269
# EGY processed successfully.
# JMIA 372
# JMIA processed successfully.
# SBH 233
# SBH processed successfully.
# ADEA 215
# ADEA processed successfully.
# FIP 224
# FIP processed successfully.
# TTC 220
# TTC processed successfully.
# CPRX 247
# CPRX processed successfully.
# TWO 293
# TWO processed successfully.
# POR 216
# POR processed successfully.
# SEM 222
# SEM processed successfully.
# PRPL 233
# PRPL processed successfully.
# CNO 218
# CNO processed successfully.
# ESNT 222
# ESNT processed successfully.
# BRKR 230
# BRKR processed successfully.
# ACIW 229
# ACIW processed successfully.
# TRIP 252
# TRIP processed successfully.
# DSL 223
# DSL processed successfully.
# CXM 224
# CXM processed successfully.
# BARK 257
# BARK processed successfully.
# VKTX 415
# VKTX processed successfully.
# SJM 220
# SJM processed successfully.
# AL 218
# AL processed successfully.
# YEXT 226
# YEXT processed successfully.
# BXMX 210
# BXMX processed successfully.
# HIW 220
# HIW processed successfully.
# DNOW 216
# DNOW processed successfully.
# OLO 246
# OLO processed successfully.
# AKR 212
# AKR processed successfully.
# EQC 213
# EQC processed successfully.
# LPRO 214
# LPRO processed successfully.
# INN 219
# INN processed successfully.
# IBKR 263
# IBKR processed successfully.
# CPT 220
# CPT processed successfully.
# HOUS 228
# HOUS processed successfully.
# BBDC 228
# BBDC processed successfully.
# SUN 232
# SUN processed successfully.
# PSN 237
# PSN processed successfully.
# ECVT 224
# ECVT processed successfully.
# AOD 222
# AOD processed successfully.
# FND 232
# FND processed successfully.
# PRVA 216
# PRVA processed successfully.
# SBAC 219
# SBAC processed successfully.
# REGN 235
# REGN processed successfully.
# VSAT 280
# VSAT processed successfully.
# KAR 215
# KAR processed successfully.
# BMEZ 215
# BMEZ processed successfully.
# AB 233
# AB processed successfully.
# SKT 217
# SKT processed successfully.
# STGW 211
# STGW processed successfully.
# ROP 235
# ROP processed successfully.
# RMBS 279
# RMBS processed successfully.
# EXAI 267
# EXAI processed successfully.
# LULU 313
# LULU processed successfully.
# BCAT 247
# BCAT processed successfully.
# NAVI 216
# NAVI processed successfully.
# SEIC 228
# SEIC processed successfully.
# CXW 235
# CXW processed successfully.
# ATAT 249
# ATAT processed successfully.
# TSCO 233
# TSCO processed successfully.
# LC 300
# LC processed successfully.
# OZK 246
# OZK processed successfully.
# EVLV 324
# EVLV processed successfully.
# ECX 114
# TREX 238
# TREX processed successfully.
# SFL 235
# SFL processed successfully.
# SAVE 463
# SAVE processed successfully.
# VRNS 239
# VRNS processed successfully.
# WAL 254
# WAL processed successfully.
# NOVA 433
# NOVA processed successfully.
# RNA 244
# RNA processed successfully.
# CE 220
# CE processed successfully.
# DNMR 349
# DNMR processed successfully.
# JBL 231
# JBL processed successfully.
# ALVO 209
# ALVO processed successfully.
# IGT 215
# IGT processed successfully.
# CNK 244
# CNK processed successfully.
# MLI 239
# MLI processed successfully.
# KSS 379
# KSS processed successfully.
# FRGE 234
# FRGE processed successfully.
# ETW 217
# ETW processed successfully.
# BROS 298
# BROS processed successfully.
# Missing required fields for GRTS. Available columns: RangeIndex(start=0, stop=0, step=1)
# AI 438
# AI processed successfully.
# NMZ 216
# NMZ processed successfully.
# CHRS 354
# CHRS processed successfully.
# EVH 231
# EVH processed successfully.
# CERT 220
# CERT processed successfully.
# NOTE 247
# NOTE processed successfully.
# DGX 228
# DGX processed successfully.
# AXL 231
# AXL processed successfully.
# SMMT 403
# SMMT processed successfully.
# LFST 224
# LFST processed successfully.
# TSEM 262
# TSEM processed successfully.
# CVNA 385
# CVNA processed successfully.
# GSM 234
# GSM processed successfully.
# ASTS 477
# ASTS processed successfully.
# GMED 227
# GMED processed successfully.
# NGL 215
# NGL processed successfully.
# CDP 214
# CDP processed successfully.
# STKL 223
# STKL processed successfully.
# NVTS 385
# NVTS processed successfully.
# SM 257
# SM processed successfully.
# HLIT 247
# HLIT processed successfully.
# NWGL 58
# CMC 219
# CMC processed successfully.
# PDO 237
# PDO processed successfully.
# SBLK 355
# SBLK processed successfully.
# CIB 218
# CIB processed successfully.
# GBCI 218
# GBCI processed successfully.
# LZ 220
# LZ processed successfully.
# LBRDK 221
# LBRDK processed successfully.
# WBX 274
# WBX processed successfully.
# ALAB 396
# ALAB processed successfully.
# LADR 230
# LADR processed successfully.
# ROK 224
# ROK processed successfully.
# PNW 215
# PNW processed successfully.
# STN 210
# STN processed successfully.
# TOUR 263
# TOUR processed successfully.
# DOX 218
# DOX processed successfully.
# ETSY 356
# ETSY processed successfully.
# CYTK 233
# CYTK processed successfully.
# MIN 201
# MIN processed successfully.
# BLDR 261
# BLDR processed successfully.
# HASI 223
# HASI processed successfully.
# LYEL 307
# LYEL processed successfully.
# KPTI 279
# KPTI processed successfully.
# XPO 239
# XPO processed successfully.
# BERY 213
# BERY processed successfully.
# HOPE 214
# HOPE processed successfully.
# MDXG 229
# MDXG processed successfully.
# KRC 227
# KRC processed successfully.
# CPRI 339
# CPRI processed successfully.
# ENLT 110
# XRX 274
# XRX processed successfully.
# MTDR 255
# MTDR processed successfully.
# PFS 212
# PFS processed successfully.
# RVT 217
# RVT processed successfully.
# TW 222
# TW processed successfully.
# SPR 254
# SPR processed successfully.
# ADX 224
# ADX processed successfully.
# KW 211
# KW processed successfully.
# BR 217
# BR processed successfully.
# IHRT 234
# IHRT processed successfully.
# MAA 217
# MAA processed successfully.
# EMN 220
# EMN processed successfully.
# SCLX 383
# SCLX processed successfully.
# NTRA 227
# NTRA processed successfully.
# CHRW 226
# CHRW processed successfully.
# GTLB 307
# GTLB processed successfully.
# RDFN 416
# RDFN processed successfully.
# ZKH 203
# ZKH processed successfully.
# GSBD 244
# GSBD processed successfully.
# MRVI 218
# MRVI processed successfully.
# ETV 216
# ETV processed successfully.
# DRI 221
# DRI processed successfully.
# ALB 332
# ALB processed successfully.
# TENB 220
# TENB processed successfully.
# OLN 237
# OLN processed successfully.
# ATAI 319
# ATAI processed successfully.
# PCVX 226
# PCVX processed successfully.
# GXO 239
# GXO processed successfully.
# XFOR 327
# XFOR processed successfully.
# TROX 235
# TROX processed successfully.
# GH 260
# GH processed successfully.
# AOS 232
# AOS processed successfully.
# PEB 215
# PEB processed successfully.
# HIVE 416
# HIVE processed successfully.
# FLYW 229
# FLYW processed successfully.
# CLS 361
# CLS processed successfully.
# UCB 212
# UCB processed successfully.
# XPRO 228
# XPRO processed successfully.
# ARWR 225
# ARWR processed successfully.
# UPWK 295
# UPWK processed successfully.
# SONO 259
# SONO processed successfully.
# PTC 223
# PTC processed successfully.
# OPTN 222
# OPTN processed successfully.
# MCRB 362
# MCRB processed successfully.
# OMF 241
# OMF processed successfully.
# DCI 215
# DCI processed successfully.
# GOGL 339
# GOGL processed successfully.
# DNLI 222
# DNLI processed successfully.
# LOMA 218
# LOMA processed successfully.
# GGAL 244
# GGAL processed successfully.
# CTKB 212
# CTKB processed successfully.
# GCI 228
# GCI processed successfully.
# SUM 227
# SUM processed successfully.
# CCK 220
# CCK processed successfully.
# HYLN 267
# HYLN processed successfully.
# AMRX 242
# AMRX processed successfully.
# LWLG 270
# LWLG processed successfully.
# SATS 242
# SATS processed successfully.
# LEV 249
# LEV processed successfully.
# WVE 277
# WVE processed successfully.
# HUM 307
# HUM processed successfully.
# RLAY 242
# RLAY processed successfully.
# NWBI 219
# NWBI processed successfully.
# DOCS 241
# DOCS processed successfully.
# LNZA 240
# LNZA processed successfully.
# ATHM 222
# ATHM processed successfully.
# RACE 265
# RACE processed successfully.
# QBTS 467
# QBTS processed successfully.
# TLSA 268
# TLSA processed successfully.
# UE 215
# UE processed successfully.
# RKT 307
# RKT processed successfully.
# TMC 292
# TMC processed successfully.
# FREY 314
# FREY processed successfully.
# WSM 231
# WSM processed successfully.
# SANA 237
# SANA processed successfully.
# CHWY 388
# CHWY processed successfully.
# PECO 221
# PECO processed successfully.
# NVX 197
# NVX processed successfully.
# PDM 213
# PDM processed successfully.
# EFXT 210
# EFXT processed successfully.
# MP 319
# MP processed successfully.
# CYH 244
# CYH processed successfully.
# GPRO 351
# GPRO processed successfully.
# ALGM 267
# ALGM processed successfully.
# AIOT 239
# AIOT processed successfully.
# J 216
# J processed successfully.
# SARO 232
# SARO processed successfully.
# ATI 244
# ATI processed successfully.
# RVTY 221
# RVTY processed successfully.
# CFFN 217
# CFFN processed successfully.
# EFX 231
# EFX processed successfully.
# SUI 218
# SUI processed successfully.
# CLX 238
# CLX processed successfully.
# FBIN 224
# FBIN processed successfully.
# OBDE 211
# OBDE processed successfully.
# UA 273
# UA processed successfully.
# SFNC 218
# SFNC processed successfully.
# ROIC 218
# ROIC processed successfully.
# EXPE 291
# EXPE processed successfully.
# VSH 228
# VSH processed successfully.
# FG 199
# FG processed successfully.
# FMC 235
# FMC processed successfully.
# MGNI 260
# MGNI processed successfully.
# ARCO 230
# ARCO processed successfully.
# EGHT 223
# EGHT processed successfully.
# TTI 258
# TTI processed successfully.
# CBSH 216
# CBSH processed successfully.
# HSIC 222
# HSIC processed successfully.
# BTU 264
# BTU processed successfully.
# MBC 212
# MBC processed successfully.
# HALO 284
# HALO processed successfully.
# WOLF 475
# WOLF processed successfully.
# TEO 217
# TEO processed successfully.
# ALK 299
# ALK processed successfully.
# ATOS 296
# ATOS processed successfully.
# VERU 274
# VERU processed successfully.
# FSLY 303
# FSLY processed successfully.
# OLPX 241
# OLPX processed successfully.
# ROKU 405
# ROKU processed successfully.
# NEO 225
# NEO processed successfully.
# ORGN 273
# ORGN processed successfully.
# LILAK 212
# LILAK processed successfully.
# RPM 222
# RPM processed successfully.
# FHB 214
# FHB processed successfully.
# BAH 227
# BAH processed successfully.
# Missing required fields for LGF-B. Available columns: RangeIndex(start=0, stop=0, step=1)
# ALNY 223
# ALNY processed successfully.
# BRSP 239
# BRSP processed successfully.
# TALK 351
# TALK processed successfully.
# FIGS 232
# FIGS processed successfully.
# PH 227
# PH processed successfully.
# CMTG 217
# CMTG processed successfully.
# VVV 221
# VVV processed successfully.
# BRBR 229
# BRBR processed successfully.
# EXTR 225
# EXTR processed successfully.
# DDD 345
# DDD processed successfully.
# SMAR 237
# SMAR processed successfully.
# AUPH 234
# AUPH processed successfully.
# INDV 291
# INDV processed successfully.
# LAUR 220
# LAUR processed successfully.
# OUT 219
# OUT processed successfully.
# MCK 228
# MCK processed successfully.
# AQMS 345
# AQMS processed successfully.
# NE 376
# NE processed successfully.
# AIV 213
# AIV processed successfully.
# DVAX 232
# DVAX processed successfully.
# ENPH 436
# ENPH processed successfully.
# HOG 265
# HOG processed successfully.
# VSTS 214
# VSTS processed successfully.
# COUR 321
# COUR processed successfully.
# RWT 232
# RWT processed successfully.
# FLS 232
# FLS processed successfully.
# HAS 244
# HAS processed successfully.
# LEG 257
# LEG processed successfully.
# BJ 214
# BJ processed successfully.
# CVBF 213
# CVBF processed successfully.
# FR 218
# FR processed successfully.
# KBR 218
# KBR processed successfully.
# SKX 285
# SKX processed successfully.
# CMA 242
# CMA processed successfully.
# YALA 231
# YALA processed successfully.
# VMC 235
# VMC processed successfully.
# BIPC 218
# BIPC processed successfully.
# FOX 214
# FOX processed successfully.
# CSTM 261
# CSTM processed successfully.
# UBSI 214
# UBSI processed successfully.
# GEO 310
# GEO processed successfully.
# LDOS 246
# LDOS processed successfully.
# CDW 233
# CDW processed successfully.
# MODG 254
# MODG processed successfully.
# WT 245
# WT processed successfully.
# CRDO 320
# CRDO processed successfully.
# WMG 221
# WMG processed successfully.
# ACM 221
# ACM processed successfully.
# KLAC 300
# KLAC processed successfully.
# NOMD 211
# NOMD processed successfully.
# JFR 217
# JFR processed successfully.
# RQI 221
# RQI processed successfully.
# TALO 267
# TALO processed successfully.
# NFE 358
# NFE processed successfully.
# PCOR 223
# PCOR processed successfully.
# CMI 222
# CMI processed successfully.
# LOGI 322
# LOGI processed successfully.
# OCUL 248
# OCUL processed successfully.
# ESRT 222
# ESRT processed successfully.
# JQC 221
# JQC processed successfully.
# TRI 212
# TRI processed successfully.
# PRGO 223
# PRGO processed successfully.
# SLQT 283
# SLQT processed successfully.
# INFA 232
# INFA processed successfully.
# MOMO 257
# MOMO processed successfully.
# LSCC 272
# LSCC processed successfully.
# LAAC 358
# LAAC processed successfully.
# LSPD 230
# LSPD processed successfully.
# BSY 227
# BSY processed successfully.
# XERS 257
# XERS processed successfully.
# ARI 247
# ARI processed successfully.
# DOV 227
# DOV processed successfully.
# PRM 240
# PRM processed successfully.
# NMRK 218
# NMRK processed successfully.
# HTZ 356
# HTZ processed successfully.
# EWBC 228
# EWBC processed successfully.
# HPP 263
# HPP processed successfully.
# FFIN 216
# FFIN processed successfully.
# TNXP 480
# TNXP processed successfully.
# BOX 227
# BOX processed successfully.
# AMBP 260
# AMBP processed successfully.
# SLDP 387
# SLDP processed successfully.
# HRB 225
# HRB processed successfully.
# TGTX 333
# TGTX processed successfully.
# BANC 247
# BANC processed successfully.
# ALLO 258
# ALLO processed successfully.
# SOLV 234
# SOLV processed successfully.
# LW 252
# LW processed successfully.
# LX 384
# LX processed successfully.
# GPC 259
# GPC processed successfully.
# NXT 340
# NXT processed successfully.
# DHT 299
# DHT processed successfully.
# RVMD 242
# RVMD processed successfully.
# CWAN 236
# CWAN processed successfully.
# JBI 240
# JBI processed successfully.
# ZUO 263
# ZUO processed successfully.
# IGR 222
# IGR processed successfully.
# PCT 336
# PCT processed successfully.
# EXPD 222
# EXPD processed successfully.
# GDDY 235
# GDDY processed successfully.
# SCI 222
# SCI processed successfully.
# VYX 216
# VYX processed successfully.
# BG 251
# BG processed successfully.
# VIK 277
# VIK processed successfully.
# SPOT 291
# SPOT processed successfully.
# IMMP 217
# IMMP processed successfully.
# AVB 214
# AVB processed successfully.
# MREO 230
# MREO processed successfully.
# AZEK 221
# AZEK processed successfully.
# VRSK 218
# VRSK processed successfully.
# CIEN 249
# CIEN processed successfully.
# ADPT 233
# ADPT processed successfully.
# MUR 246
# MUR processed successfully.
# QFIN 289
# QFIN processed successfully.
# PGEN 254
# PGEN processed successfully.
# GOF 312
# GOF processed successfully.
# DV 253
# DV processed successfully.
# SQM 280
# SQM processed successfully.
# RBBN 226
# RBBN processed successfully.
# HLX 257
# HLX processed successfully.
# SNV 228
# SNV processed successfully.
# FRO 384
# FRO processed successfully.
# VMEO 233
# VMEO processed successfully.
# ZWS 219
# ZWS processed successfully.
# DAN 263
# DAN processed successfully.
# SEE 226
# SEE processed successfully.
# STLD 234
# STLD processed successfully.
# HRTX 249
# HRTX processed successfully.
# CNX 242
# CNX processed successfully.
# REZI 215
# REZI processed successfully.
# HYT 236
# HYT processed successfully.
# BIIB 258
# BIIB processed successfully.
# RELY 252
# RELY processed successfully.
# CUK 375
# CUK processed successfully.
# DDL 295
# DDL processed successfully.
# ZION 241
# ZION processed successfully.
# CNDT 223
# CNDT processed successfully.
# IONS 233
# IONS processed successfully.
# RMD 233
# RMD processed successfully.
# PWR 250
# PWR processed successfully.
# NOC 228
# NOC processed successfully.
# FINV 224
# FINV processed successfully.
# ABUS 237
# ABUS processed successfully.
# BLK 227
# BLK processed successfully.
# BBIO 253
# BBIO processed successfully.
# ACVA 219
# ACVA processed successfully.
# BTBT 475
# BTBT processed successfully.
# HSY 268
# HSY processed successfully.
# ENVX 436
# ENVX processed successfully.
# VEEV 233
# ...
# COF 245
# COF processed successfully.
# AVAL 155
# EQR 217
# EQR processed successfully.
# NWSA 223
# NWSA processed successfully.
# TMO 247
# TMO processed successfully.
# RPRX 235
# RPRX processed successfully.
# SKM 238
# SKM processed successfully.
# LVS 331
# LVS processed successfully.
# EIX 231
# EIX processed successfully.
# JOBY 480
# JOBY processed successfully.
# GME 479
# GME processed successfully.
# NOV 256
# NOV processed successfully.
# LAZR 461
# LAZR processed successfully.
# LILM 478
# LILM processed successfully.
# SYF 268
# SYF processed successfully.
# QXO 246
# QXO processed successfully.
# CHPT 467
# CHPT processed successfully.
# CDE 405
# CDE processed successfully.
# YPF 263
# YPF processed successfully.
# ASML 428
# ASML processed successfully.
# TOST 338
# TOST processed successfully.
# MQ 256
# MQ processed successfully.
# FLEX 257
# FLEX processed successfully.
# DXCM 329
# DXCM processed successfully.
# PNC 252
# PNC processed successfully.
# ETN 261
# ETN processed successfully.
# OTIS 239
# OTIS processed successfully.
# WM 242
# WM processed successfully.
# APO 244
# APO processed successfully.
# CB 249
# CB processed successfully.
# IR 232
# IR processed successfully.
# HWM 281
# HWM processed successfully.
# CSGP 246
# CSGP processed successfully.
# ADP 244
# ADP processed successfully.
# AMRN 295
# AMRN processed successfully.
# VTR 232
# VTR processed successfully.
# NWL 311
# NWL processed successfully.
# PATH 439
# PATH processed successfully.
# DD 245
# DD processed successfully.
# PSX 260
# PSX processed successfully.
# AGI 314
# AGI processed successfully.
# CCCS 225
# CCCS processed successfully.
# AU 388
# AU processed successfully.
# ADT 272
# ADT processed successfully.
# ACI 275
# ACI processed successfully.
# ABNB 340
# ABNB processed successfully.
# COMP 301
# COMP processed successfully.
# GNW 221
# GNW processed successfully.
# FTI 243
# FTI processed successfully.
# CLVT 221
# CLVT processed successfully.
# GEHC 278
# GEHC processed successfully.
# ON 385
# ON processed successfully.
# NFLX 378
# NFLX processed successfully.
# JHX 223
# JHX processed successfully.
# CCI 247
# CCI processed successfully.
# CCJ 408
# CCJ processed successfully.
# SNN 340
# SNN processed successfully.
# NCLH 431
# NCLH processed successfully.
# ALIT 235
# ALIT processed successfully.
# EQT 307
# EQT processed successfully.
# ADBE 330
# ADBE processed successfully.
# MLCO 291
# MLCO processed successfully.
# COST 303
# COST processed successfully.
# IVZ 238
# IVZ processed successfully.
# CFG 251
# CFG processed successfully.
# TAL 413
# TAL processed successfully.
# TTD 326
# TTD processed successfully.
# NI 234
# NI processed successfully.
# ZTS 232
# ZTS processed successfully.
# WPM 294
# WPM processed successfully.
# PAA 252
# PAA processed successfully.
# VIPS 290
# VIPS processed successfully.
# CLF 397
# CLF processed successfully.
# BIP 218
# BIP processed successfully.
# TGT 334
# TGT processed successfully.
# KOS 340
# KOS processed successfully.
# FER 211
# FER processed successfully.
# AMT 245
# AMT processed successfully.
# DKNG 424
# DKNG processed successfully.
# PSNY 435
# PSNY processed successfully.
# LIN 271
# LIN processed successfully.
# BSAC 226
# BSAC processed successfully.
# CAG 273
# CAG processed successfully.
# ADM 258
# ADM processed successfully.
# IEP 323
# IEP processed successfully.
# TIMB 226
# TIMB processed successfully.
# CAT 301
# CAT processed successfully.
# TUYA 246
# TUYA processed successfully.
# ALC 271
# ALC processed successfully.
# EBAY 306
# EBAY processed successfully.
# TMUS 322
# TMUS processed successfully.
# ELAN 237
# ELAN processed successfully.
# SYY 247
# SYY processed successfully.
# MMC 229
# MMC processed successfully.
# KT 252
# KT processed successfully.
# FTS 212
# FTS processed successfully.
# NTR 244
# NTR processed successfully.
# CTSH 256
# CTSH processed successfully.
# ADI 280
# ADI processed successfully.
# AEM 335
# AEM processed successfully.
# PEG 228
# PEG processed successfully.
# SMCI 480
# SMCI processed successfully.
# VLY 242
# VLY processed successfully.
# TV 233
# TV processed successfully.
# RTO 304
# RTO processed successfully.
# AFL 239
# AFL processed successfully.
# BCH 216
# BCH processed successfully.
# SHG 244
# SHG processed successfully.
# TECK 266
# TECK processed successfully.
# BAX 239
# BAX processed successfully.
# RBLX 419
# RBLX processed successfully.
# PCAR 250
# PCAR processed successfully.
# RITM 364
# RITM processed successfully.
# NXE 352
# NXE processed successfully.
# CNC 311
# CNC processed successfully.
# SE 366
# SE processed successfully.
# IQ 457
# IQ processed successfully.
# MCHP 308
# MCHP processed successfully.
# FHN 269
# FHN processed successfully.
# AEP 252
# AEP processed successfully.
# PR 296
# PR processed successfully.
# AMGN 267
# AMGN processed successfully.
# NLY 339
# NLY processed successfully.
# SQ 457
# SQ processed successfully.
# FIS 225
# FIS processed successfully.
# MMM 317
# MMM processed successfully.
# OWL 261
# OWL processed successfully.
# MPW 427
# MPW processed successfully.
# GERN 294
# GERN processed successfully.
# GIS 247
# GIS processed successfully.
# FCEL 468
# FCEL processed successfully.
# DEO 305
# DEO processed successfully.
# XEL 246
# XEL processed successfully.
# OTLY 309
# OTLY processed successfully.
# MRO 332
# MRO processed successfully.
# GEN 244
# GEN processed successfully.
# LOW 272
# LOW processed successfully.
# EOG 264
# EOG processed successfully.
# TS 344
# TS processed successfully.
# IAG 371
# IAG processed successfully.
# ICE 240
# ICE processed successfully.
# EMR 238
# EMR processed successfully.
# FI 257
# FI processed successfully.
# FAST 248
# FAST processed successfully.
# OPEN 479
# OPEN processed successfully.
# FE 270
# FE processed successfully.
# SLF 213
# SLF processed successfully.
# PBA 221
# PBA processed successfully.
# BB 385
# BB processed successfully.
# OKE 262
# OKE processed successfully.
# PGR 250
# PGR processed successfully.
# MET 252
# MET processed successfully.
# FMS 302
# FMS processed successfully.
# HL 422
# HL processed successfully.
# PARA 361
# PARA processed successfully.
# EW 263
# EW processed successfully.
# LUV 397
# LUV processed successfully.
# ZTO 253
# ZTO processed successfully.
# PINS 366
# PINS processed successfully.
# HOOD 478
# HOOD processed successfully.
# VRN 325
# VRN processed successfully.
# UNP 248
# UNP processed successfully.
# CNI 232
# CNI processed successfully.
# INVH 243
# INVH processed successfully.
# BA 469
# BA processed successfully.
# WELL 242
# WELL processed successfully.
# NTES 354
# NTES processed successfully.
# DVN 395
# DVN processed successfully.
# ACN 250
# ACN processed successfully.
# ARCC 322
# ARCC processed successfully.
# SSL 331
# SSL processed successfully.
# FTNT 330
# FTNT processed successfully.
# SRE 236
# SRE processed successfully.
# HMY 427
# HMY processed successfully.
# GMAB 362
# GMAB processed successfully.
# AIG 258
# AIG processed successfully.
# DAL 409
# DAL processed successfully.
# TCOM 348
# TCOM processed successfully.
# AAL 474
# AAL processed successfully.
# CNP 232
# CNP processed successfully.
# HON 303
# HON processed successfully.
# DHR 299
# DHR processed successfully.
# KIM 234
# KIM processed successfully.
# AVTR 244
# AVTR processed successfully.
# JCI 237
# JCI processed successfully.
# FITB 266
# FITB processed successfully.
# KKR 279
# KKR processed successfully.
# LOT 211
# LOT processed successfully.
# CRH 329
# CRH processed successfully.
# PSO 263
# PSO processed successfully.
# SBS 227
# SBS processed successfully.
# TME 355
# TME processed successfully.
# CTVA 242
# CTVA processed successfully.
# HST 243
# HST processed successfully.
# MNST 261
# MNST processed successfully.
# DOC 243
# DOC processed successfully.
# BTE 296
# BTE processed successfully.
# DOW 331
# DOW processed successfully.
# SBSW 440
# SBSW processed successfully.
# AES 360
# AES processed successfully.
# AXP 334
# AXP processed successfully.
# WBA 470
# WBA processed successfully.
# BX 288
# BX processed successfully.
# MCD 369
# MCD processed successfully.
# KR 280
# KR processed successfully.
# ICL 254
# ICL processed successfully.
# WY 242
# WY processed successfully.
# BK 256
# BK processed successfully.
# CTRA 334
# CTRA processed successfully.
# BMO 217
# BMO processed successfully.
# RIVN 480
# RIVN processed successfully.
# RIG 434
# RIG processed successfully.
# UPS 339
# UPS processed successfully.
# PPL 254
# PPL processed successfully.
# XPEV 479
# XPEV processed successfully.
# AQN 242
# AQN processed successfully.
# DUK 268
# DUK processed successfully.
# CHT 214
# CHT processed successfully.
# GLW 341
# GLW processed successfully.
# AGNC 471
# AGNC processed successfully.
# MT 349
# MT processed successfully.
# LI 475
# LI processed successfully.
# CNH 288
# CNH processed successfully.
# CL 300
# CL processed successfully.
# PLUG 480
# PLUG processed successfully.
# AMAT 420
# AMAT processed successfully.
# MA 252
# MA processed successfully.
# LU 360
# LU processed successfully.
# D 328
# D processed successfully.
# CARR 275
# CARR processed successfully.
# LLY 365
# LLY processed successfully.
# MRVL 438
# MRVL processed successfully.
# O 430
# O processed successfully.
# TKC 235
# TKC processed successfully.
# YMM 251
# YMM processed successfully.
# LCID 480
# LCID processed successfully.
# HAL 405
# HAL processed successfully.
# CPRT 261
# CPRT processed successfully.
# RLX 297
# RLX processed successfully.
# STM 438
# STM processed successfully.
# GFI 391
# GFI processed successfully.
# TLRY 471
# TLRY processed successfully.
# OXY 480
# OXY processed successfully.
# TXN 326
# TXN processed successfully.
# BCE 239
# BCE processed successfully.
# RF 284
# RF processed successfully.
# IBM 369
# IBM processed successfully.
# UNH 295
# UNH processed successfully.
# PLD 260
# PLD processed successfully.
# AUR 395
# AUR processed successfully.
# CRM 337
# CRM processed successfully.
# CP 243
# CP processed successfully.
# PHG 303
# PHG processed successfully.
# LUMN 437
# LUMN processed successfully.
# CM 222
# CM processed successfully.
# KEY 299
# KEY processed successfully.
# HPQ 275
# HPQ processed successfully.
# NGG 248
# NGG processed successfully.
# TLK 248
# TLK processed successfully.
# BKR 322
# BKR processed successfully.
# HD 302
# HD processed successfully.
# CCL 474
# CCL processed successfully.
# EXC 280
# EXC processed successfully.
# LPL 250
# LPL processed successfully.
# SOFI 480
# SOFI processed successfully.
# PYPL 464
# PYPL processed successfully.
# ALTM 416
# ALTM processed successfully.
# TRP 237
# TRP processed successfully.
# ARM 480
# ARM processed successfully.
# VICI 296
# VICI processed successfully.
# SNAP 474
# SNAP processed successfully.
# KDP 313
# KDP processed successfully.
# GE 376
# GE processed successfully.
# UGP 231
# UGP processed successfully.
# SO 272
# SO processed successfully.
# MU 480
# MU processed successfully.
# SBUX 386
# SBUX processed successfully.
# QCOM 456
# QCOM processed successfully.
# GM 400
# GM processed successfully.
# TJX 261
# TJX processed successfully.
# TEVA 325
# TEVA processed successfully.
# NEM 445
# NEM processed successfully.
# BEKE 444
# BEKE processed successfully.
# COP 330
# COP processed successfully.
# SAP 346
# SAP processed successfully.
# VTRS 268
# VTRS processed successfully.
# NKE 456
# NKE processed successfully.
# CPNG 403
# CPNG processed successfully.
# APH 307
# APH processed successfully.
# KHC 359
# KHC processed successfully.
# SHOP 383
# SHOP processed successfully.
# WMB 268
# WMB processed successfully.
# BN 249
# BN processed successfully.
# KGC 384
# KGC processed successfully.
# SUZ 233
# SUZ processed successfully.
# BNS 231
# BNS processed successfully.
# MS 330
# MS processed successfully.
# GILD 300
# GILD processed successfully.
# RIO 389
# RIO processed successfully.
# CVS 413
# CVS processed successfully.
# SU 272
# SU processed successfully.
# MDT 272
# MDT processed successfully.
# KEP 224
# KEP processed successfully.
# LRCX 461
# LRCX processed successfully.
# HPE 361
# HPE processed successfully.
# CVE 344
# CVE processed successfully.
# Missing required fields for BRK-B. Available columns: RangeIndex(start=0, stop=0, step=1)
# SID 263
# SID processed successfully.
# RTX 339
# RTX processed successfully.
# MDLZ 298
# MDLZ processed successfully.
# TFC 294
# TFC processed successfully.
# TM 277
# TM processed successfully.
# PDD 478
# PDD processed successfully.
# CMG 414
# CMG processed successfully.
# JD 478
# JD processed successfully.
# PEP 308
# PEP processed successfully.
# GGB 259
# GGB processed successfully.
# ENIC 227
# ENIC processed successfully.
# RY 218
# RY processed successfully.
# SLB 419
# SLB processed successfully.
# FCX 413
# FCX processed successfully.
# HBAN 306
# HBAN processed successfully.
# AMCR 266
# AMCR processed successfully.
# EPD 352
# EPD processed successfully.
# BSX 294
# BSX processed successfully.
# TU 227
# TU processed successfully.
# CX 325
# CX processed successfully.
# PM 306
# PM processed successfully.
# USB 304
# USB processed successfully.
# E 272
# E processed successfully.
# HMC 255
# HMC processed successfully.
# AMD 480
# AMD processed successfully.
# AEG 307
# AEG processed successfully.
# ORCL 373
# ORCL processed successfully.
# Missing required fields for ORAN. Available columns: RangeIndex(start=0, stop=0, step=1)
# VIV 226
# VIV processed successfully.
# BRFS 242
# BRFS processed successfully.
# V 325
# V processed successfully.
# SCHW 306
# SCHW processed successfully.
# MO 420
# MO processed successfully.
# ABT 303
# ABT processed successfully.
# GOLD 474
# GOLD processed successfully.
# TD 279
# TD processed successfully.
# BUD 318
# BUD processed successfully.
# ABBV 289
# ABBV processed successfully.
# MFC 225
# MFC processed successfully.
# DB 336
# DB processed successfully.
# DIS 433
# DIS processed successfully.
# CVX 400
# CVX processed successfully.
# RELX 339
# RELX processed successfully.
# C 421
# C processed successfully.
# CIG 237
# CIG processed successfully.
# KVUE 295
# KVUE processed successfully.
# NIO 480
# NIO processed successfully.
# CSX 335
# CSX processed successfully.
# KMI 375
# KMI processed successfully.
# NVS 338
# NVS processed successfully.
# STLA 450
# STLA processed successfully.
# PLTR 480
# PLTR processed successfully.
# BSBR 231
# BSBR processed successfully.
# UBER 471
# UBER processed successfully.
# BMY 365
# BMY processed successfully.
# CNQ 285
# CNQ processed successfully.
# GSK 401
# GSK processed successfully.
# NEE 356
# NEE processed successfully.
# EC 372
# EC processed successfully.
# PCG 278
# PCG processed successfully.
# ASX 334
# ASX processed successfully.
# ENB 300
# ENB processed successfully.
# META 476
# META processed successfully.
# BTI 410
# BTI processed successfully.
# WBD 444
# WBD processed successfully.
# GRAB 462
# GRAB processed successfully.
# TTE 329
# TTE processed successfully.
# PG 309
# PG processed successfully.
# BABA 480
# BABA processed successfully.
# JNJ 308
# JNJ processed successfully.
# UL 356
# UL processed successfully.
# UMC 372
# UMC processed successfully.
# SNY 332
# SNY processed successfully.
# MRK 366
# MRK processed successfully.
# BHP 388
# BHP processed successfully.
# HDB 244
# HDB processed successfully.
# VOD 374
# VOD processed successfully.
# BP 452
# BP processed successfully.
# EQNR 398
# EQNR processed successfully.
# TSLA 480
# TSLA processed successfully.
# JPM 367
# JPM processed successfully.
# ET 396
# ET processed successfully.
# NMR 226
# NMR processed successfully.
# UBS 340
# UBS processed successfully.
# NU 473
# NU processed successfully.
# ERIC 375
# ERIC processed successfully.
# AZN 376
# AZN processed successfully.
# AMX 224
# AMX processed successfully.
# SHEL 387
# SHEL processed successfully.
# TAK 234
# TAK processed successfully.
# ING 307
# ING processed successfully.
# NVO 433
# NVO processed successfully.
# WFC 381
# WFC processed successfully.
# BCS 370
# BCS processed successfully.
# IBN 317
# IBN processed successfully.
# HSBC 357
# HSBC processed successfully.
# PBR 440
# PBR processed successfully.
# CMCSA 326
# CMCSA processed successfully.
# F 472
# F processed successfully.
# CSCO 405
# CSCO processed successfully.
# NWG 319
# NWG processed successfully.
# INFY 312
# INFY processed successfully.
# VZ 440
# VZ processed successfully.
# VALE 449
# VALE processed successfully.
# INTC 480
# INTC processed successfully.
# KO 455
# KO processed successfully.
# WMT 435
# WMT processed successfully.
# XOM 424
# XOM processed successfully.
# HLN 347
# HLN processed successfully.
# AVGO 471
# AVGO processed successfully.
# ITUB 261
# ITUB processed successfully.
# TSM 480
# TSM processed successfully.
# GOOG 476
# GOOG processed successfully.
# WIT 263
# WIT processed successfully.
# BBD 270
# BBD processed successfully.
# NOK 445
# NOK processed successfully.
# TEF 292
# TEF processed successfully.
# PFE 480
# PFE processed successfully.
# BBVA 300
# BBVA processed successfully.
# GOOGL 479
# GOOGL processed successfully.
# T 457
# T processed successfully.
# MSFT 480
# MSFT processed successfully.
# BAC 438
# BAC processed successfully.
# AMZN 480
# AMZN processed successfully.
# MUFG 262
# MUFG processed successfully.
# MFG 239
# MFG processed successfully.
# AAPL 480
# AAPL processed successfully.
# SAN 344
# SAN processed successfully.
# LYG 348
# LYG processed successfully.
# ABEV 324
# ABEV processed successfully.
# SMFG 248
# SMFG processed successfully.
# NVDA 480
# NVDA processed successfully.

# %% [markdown]
# # DATA PROCESSING AND SIGNALING

# %%
RESULT_INDEXER = 0
COMBO_INDEXER = 0
stocks_to_trade = pd.DataFrame(columns=['Strategy','Date','Ticker','Target Entry','Volume Spike','Price Spike','Previous Day Close','Signal Time', 'Shares', 'Stop Price', 'Sell Price', 'Backup Sell Time'])

for strategy in combinations:
    print(strategy,(datetime.now() - start_clock))
    tickers = list(stockies.keys())
    for ticker in tickers:

###########################################  CALCULATE SIGNALS FOR BACKTEST  ###########################################

        #Checks for Highest Daily Volume
        high_vol_sig = np.where(stockies[ticker]['Volume'] == stockies[ticker].groupby('Date')['Volume'].transform('max'),'True','False')
        stockies[ticker]['high_vol_sig'] = high_vol_sig
        #Checks for price spike 10x greater than 
        price_sig = np.where((stockies[ticker]['High']-stockies[ticker]['Day_Open_Low'])/stockies[ticker]['Day_Open_Low'] >= strategy[price_spike_thresh_index],'True','False')
        stockies[ticker]['price_sig'] = price_sig
        #Checks that the spike was before 12 pm (tied to highest daily volume)
        before_time = np.where(stockies[ticker]['Time'] <= strategy[time_sig_thresh_index], 'True','False')
        stockies[ticker]['before_time'] = before_time 
        #Checks that spike was a green bar
        green_bar = np.where(stockies[ticker]['Color_Bar'] == 'Green', 'True','False')
        stockies[ticker]['green_bar'] = green_bar
        #Checks for volume spike 10x greater than 10day average
        vol_spike_sig = np.where(stockies[ticker]['Volume'] > strategy[vol_spike_thresh_index] * stockies[ticker]['10_Day_Avg_Vol'],'True','False')
        stockies[ticker]['vol_spike_sig'] = vol_spike_sig
        #Checks that the spike high was the highest price of the day
        high_price_sig = np.where(stockies[ticker]['High'] >= stockies[ticker].groupby('Date')['Close'].transform('max'),'True','False')
        stockies[ticker]['high_price_sig'] = high_price_sig
        #Checks to see if it time is equal to the sell_time threshold set by user
        stockies[ticker]['sell_time'] = np.where(stockies[ticker]['Time'] == strategy[sell_time_threshold_index],'True','False')
        #Finds High of the Day
        stockies[ticker]['high_of_day'] = stockies[ticker].groupby('Date')['High'].transform('max')

        #Checks all conditions
        stockies[ticker]['Grab_Price_Signal'] = np.where((high_vol_sig == 'True') 
                                                         & (vol_spike_sig == 'True') 
                                                         & (price_sig == 'True') 
                                                         & (high_price_sig == 'True') 
                                                         # & (green_bar == 'True') 
                                                         & (before_time == 'True'),
                                                         'True','False')

    ################################ INPUT BUY AND SELL SIGNALS  ##################################################

        #Find a way to turn on and off signals and rules to be 'True' 'False' 'Ignore' - yet still works with backtest framework

        #Checks that the close was lower than the VWAP (maybe in backtest)
        stockies[ticker]['Close_Condition'] = 'False'

        #Temp Variables for backtest (row by row iteration)
        #Create temporary signal day variable that signaled whether or not the price_to_buy_signal was triggered during that day
        TEMP_SIGNAL_DAY = stockies[ticker]['Date'][0] - timedelta(days=10)

        #Initially set not to trigger and gets set on price_buy_signal
        TARGET_ENTRY_PRICE = 0 
        TARGET_ENTRY_PRICE_2 = 0
        TEMP_SIGNAL_TIME = time(hour = 19, minute = 30, second = 0)
        
        VOLUME_SPIKE = 0
        PRICE_SPIKE = 0

        #TO DEBUG - WILL PRINT RAW DATA OF EACH STOCK WITH ALL PRECALCULATIONS AND SIGNALS
        # # Create the directory path
        # directory = f'./daily_signals/details/{str(date.today() + timedelta(days=1))}'
        # os.makedirs(directory, exist_ok=True)  # This will create all necessary parent directories
        
        # # Now you can safely save your files
        # output_file_path_ticker = f'{directory}/{ticker}_signals_.xlsx'
        # stockies[ticker].to_excel(output_file_path_ticker, index=False, header=True)

        #Iterate over rows to see which rows meet the close condition and the all clear to buy signal (pending final signal: price cross)
        #Unique to this strategy's backtest. Could be a part of inserting variables and signals before BACKTEST SECTION
        
        for index, row in stockies[ticker].iterrows(): 
            
            if (row['Grab_Price_Signal'] == 'True') & (row['Date'] == day_of_backtest.date()):
                TEMP_SIGNAL_DAY = row['Date']
                TARGET_ENTRY_PRICE = row['VWAP']
                TEMP_SIGNAL_TIME = row['Time']
                VOLUME_SPIKE = row['Volume']/row['10_Day_Avg_Vol']
                PRICE_SPIKE = (row['High']-row['Day_Open_Low'])/row['Day_Open_Low']
                YESTERDAY_HIGH = row['high_of_day']

            if (row['Close']<=TARGET_ENTRY_PRICE) & (row['Day_Close'] == True) & (row['Date'] == TEMP_SIGNAL_DAY):
                print('Got in thur')
                stocks_to_trade.at[RESULT_INDEXER,'Previous Day Close'] = row['Close']
                stocks_to_trade.at[RESULT_INDEXER,'Strategy'] = COMBO_INDEXER
                stocks_to_trade.at[RESULT_INDEXER,'Ticker'] = row['Ticker']
                stocks_to_trade.at[RESULT_INDEXER,'Shares'] = ACCOUNT_SIZE*ALLOCATION/TARGET_ENTRY_PRICE
                stocks_to_trade.at[RESULT_INDEXER,'Target Entry'] = TARGET_ENTRY_PRICE
                stocks_to_trade.at[RESULT_INDEXER,'Date'] = row['Date']
                stocks_to_trade.at[RESULT_INDEXER,'Signal Time'] = TEMP_SIGNAL_TIME
                stocks_to_trade.at[RESULT_INDEXER,'Volume Spike'] = VOLUME_SPIKE
                stocks_to_trade.at[RESULT_INDEXER,'Price Spike'] = PRICE_SPIKE
                stocks_to_trade.at[RESULT_INDEXER,'Time Threshold'] = strategy[time_sig_thresh_index]
                stocks_to_trade.at[RESULT_INDEXER,'Sell_Time'] = strategy[sell_time_threshold_index]
                
                # Calculate Stop Price and Sell Price
                stop_price = TARGET_ENTRY_PRICE + (TARGET_ENTRY_PRICE * strategy[stop_index])
                sell_price = TARGET_ENTRY_PRICE - (TARGET_ENTRY_PRICE * strategy[target_index])
                stocks_to_trade.at[RESULT_INDEXER,'Stop Price'] = stop_price
                stocks_to_trade.at[RESULT_INDEXER,'Sell Price'] = sell_price

                RESULT_INDEXER +=1                
    COMBO_INDEXER +=1 
    
stocks_to_trade = pd.merge(stocks_to_trade,ticker_list[['Ticker','Market Cap','Sector','Float']],on = 'Ticker', how = 'left')  
stocks_to_trade['Market Capitalization'] = (stocks_to_trade['Market Cap'].astype(float)/1000000).astype(str) + 'M'
stocks_to_trade['Shares Float'] = (stocks_to_trade['Float'].astype(float)/1000000).astype(str) + 'M'
stocks_to_trade.sort_values(by = 'Market Capitalization',ascending = True,inplace = True)
output_file_path = './daily_screener_signals/' + str(day_of_backtest.date()) + timedelta(days=1)'.xlsx'
stocks_to_trade.to_excel(output_file_path, index=True, header=True)

print(datetime.now() - start_clock)
# Out:
# (0.1, 0.1, 0.05, 5, 0.05, datetime.time(12, 30), datetime.time(10, 30), datetime.time(15, 30)) 0:10:51.483569
# Got in thur
# Got in thur
# Got in thur
# Got in thur
# Got in thur
# Got in thur
# Got in thur
# Got in thur
# Got in thur
# Got in thur
# Got in thur
# Got in thur
# 0:13:07.611705
